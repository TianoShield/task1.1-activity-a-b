# %% [markdown]
# # Integrated EDK II Issue Triage Framework
# ## Tasks: Invalid Detection → Duplicate Detection → Priority Classification → Bug Assignment
#
# > **Scope: 37 labeled issues** (consistent across all tasks — issues with known `First Assignee`)
#
# **Best models (active by default):**
# - **Invalid Detection** : `claude-sonnet-4-6` System A (catches invalids)
# - **Duplicate Detection**: `claude-sonnet-4-6` System A (perfect score on 2-GT; zero FP)
# - **Prioritization**    : `claude-sonnet-4-6` System A
# - **Bug Assignment**    : `gpt-5.5` System A
# Run cells top to bottom. Each task saves results to Google Drive under `DRIVE_DIR/results/`.

# %%
# ============================================================
# CELL 1 — Install dependencies
# ============================================================
# !pip install openai anthropic chromadb sentence-transformers \
             rank_bm25 pandas scikit-learn tqdm requests -q

# %%
# ============================================================
# CELL 2 — Local storage (no Google Drive — plain server directories)
# ============================================================
import os

DRIVE_DIR   = os.path.expanduser('~/triage_framework')   # everything lives under your home dir
RESULTS_DIR = f'{DRIVE_DIR}/results'
CHROMA_DIR  = f'{DRIVE_DIR}/chroma_db'
DATA_DIR    = f'{DRIVE_DIR}/data'

for d in [RESULTS_DIR, CHROMA_DIR, DATA_DIR]:
    os.makedirs(d, exist_ok=True)

print(f'DATA_DIR   : {DATA_DIR}')
print(f'RESULTS_DIR: {RESULTS_DIR}')
print(f'CHROMA_DIR : {CHROMA_DIR}')
print('\nIf you have full-edkII-dd.csv (ground-truth reference, optional), copy it to:')
print(f'  {DATA_DIR}/full-edkII-dd.csv')
print('e.g. from your laptop:  scp full-edkII-dd.csv nsiavash@qas1.vast.uccs.edu:' + DATA_DIR + '/')
# Out:
# DATA_DIR   : /home/nsiavash/triage_framework/data
# RESULTS_DIR: /home/nsiavash/triage_framework/results
# CHROMA_DIR : /home/nsiavash/triage_framework/chroma_db
#
# If you have full-edkII-dd.csv (ground-truth reference, optional), copy it to:
#   /home/nsiavash/triage_framework/data/full-edkII-dd.csv
# e.g. from your laptop:  scp full-edkII-dd.csv nsiavash@qas1.vast.uccs.edu:/home/nsiavash/triage_framework/data/

# %%
# ============================================================
# CELL 3 — Config & API keys
# ============================================================
import os, getpass

def _get_secret(env_name, prompt, secret=True):
    """Read from an environment variable first, else prompt once."""
    val = os.environ.get(env_name, '')
    if val:
        return val
    ask = getpass.getpass if secret else input
    return ask(f'{prompt} (or Ctrl+C to skip): ').strip()

# ── OpenAI ───────────────────────────────────────────────────
OPENAI_API_KEY    = os.environ.get('OPENAI_API_KEY', '')
OPENAI_ORG_ID     = os.environ.get('OPENAI_ORG_ID', '')
OPENAI_PROJECT_ID = os.environ.get('OPENAI_PROJECT_ID', '')
if not OPENAI_API_KEY:
    try:
        OPENAI_API_KEY = _get_secret('OPENAI_API_KEY', 'OpenAI API key')
    except KeyboardInterrupt:
        OPENAI_API_KEY = ''
os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

# ── Anthropic ────────────────────────────────────────────────
ANTHROPIC_API_KEY = os.environ.get('ANTHROPIC_API_KEY', '')

# ── GitHub (for live issue fetch — needs a token for ~3,500+ issues) ──
GITHUB_TOKEN = os.environ.get('GITHUB_TOKEN', '')
if not GITHUB_TOKEN:
    try:
        GITHUB_TOKEN = _get_secret(
            'GITHUB_TOKEN',
            'GitHub personal access token (raises rate limit from 60/hr to 5000/hr)'
        )
    except KeyboardInterrupt:
        GITHUB_TOKEN = ''

print(f"OpenAI key    : {'set' if OPENAI_API_KEY    else 'NOT SET'}")
print(f"OpenAI org    : {'set' if OPENAI_ORG_ID     else 'not set'}")
print(f"OpenAI project: {'set' if OPENAI_PROJECT_ID else 'not set'}")
print(f"Anthropic key : {'set' if ANTHROPIC_API_KEY  else 'not set'}")
print(f"GitHub token  : {'set' if GITHUB_TOKEN       else 'not set (rate-limited to 60 req/hr)'}")

# NOTE: the input dataset is fetched LIVE from the GitHub API (see CELL 4).
# This CSV is only used, if present, as a ground-truth REFERENCE for the
# small set of issues we have curated labels for (priority / first-assignee)
# — it's optional, not a hard requirement.
_csv_candidates = [
    f'{DATA_DIR}/full-edkII-dd.csv',
    f'{DRIVE_DIR}/full-edkII-dd.csv',
    os.path.expanduser('~/full-edkII-dd.csv'),
]
GITHUB_CSV = next((p for p in _csv_candidates if os.path.exists(p)), None)

if GITHUB_CSV is None:
    print("\nℹ️  No ground-truth CSV found (full-edkII-dd.csv) — that's fine, the pipeline")
    print("   will run as pure production inference over all fetched GitHub issues,")
    print("   with no evaluation metrics (no known-correct labels to compare against).")
    print(f"   To enable eval, copy it to: {DATA_DIR}/full-edkII-dd.csv")
else:
    print(f'\n✅ Ground-truth reference CSV found: {GITHUB_CSV}')

XML_FILES = [
    f'{DATA_DIR}/tianocore_closed_0_1000.xml',
    f'{DATA_DIR}/tianocore_closed_1000_2000.xml',
    f'{DATA_DIR}/tianocore_closed_2000_3000.xml',
    f'{DATA_DIR}/tianocore_closed_3000_4000.xml',
    f'{DATA_DIR}/tianocore_closed_4000_5000.xml',
]

# ── RAG flag ─────────────────────────────────────────────────
# Set to True ONLY if you want to use System B (RAG) for any task.
# If all tasks use System A (no RAG), keep this False to skip
# XML ingestion and Bugzilla indexing — saves significant setup time.
USE_RAG = False   # ← change to True if switching any task to System B

# ── Models ────────────────────────────────────────────────────
# Best models are ACTIVE (uncommented).
# Switch by commenting/uncommenting below.

# ── BEST MODELS (one per task, set individually in each task cell) ─────────
# Invalid Detection  → claude-sonnet-4-6 (System A)
# Duplicate Detect.  → claude-sonnet-4-6 (System A)
# Prioritization     → claude-sonnet-4-6 (System A)
# Bug Assignment     → gpt-5.5           (System A)

# ── All available models (for reference / batch runs) ────────
OPENAI_MODELS = [
    # 'gpt-4o-mini',
    # 'gpt-4o',
    # 'gpt-4.1-mini',
    # 'gpt-4.1',
    # 'gpt-5.4-mini',
    # 'gpt-5.4',
    'gpt-5.5',       # ← best for bug assignment
]

CLAUDE_MODELS = [
    # 'claude-haiku-4-5',
    'claude-sonnet-4-6',   # ← best for invalid, duplicate, priority
    # 'claude-opus-4-7',
] if ANTHROPIC_API_KEY else []

ALL_MODELS = OPENAI_MODELS + CLAUDE_MODELS

_RESPONSES_API_MODELS = {
    'gpt-5', 'gpt-5-mini', 'gpt-5.1', 'gpt-5.4', 'gpt-5.4-mini',
    'gpt-5.4-nano', 'gpt-5.4-pro', 'gpt-5.5', 'gpt-5.5-pro',
    'o3', 'o3-mini', 'o4-mini',
}

print(f'\nActive models ({len(ALL_MODELS)}): {ALL_MODELS}')
# Out:
# GitHub personal access token (raises rate limit from 60/hr to 5000/hr) (or Ctrl+C to skip): ··········
# OpenAI key    : set
# OpenAI org    : not set
# OpenAI project: not set
# Anthropic key : not set
# GitHub token  : set
#
# ✅ Ground-truth reference CSV found: /home/nsiavash/triage_framework/data/full-edkII-dd.csv
#
# Active models (1): ['gpt-5.5']

# %%
# ============================================================
# CELL 3b — Local model setup (Ollama on MULTIPLE GPUs at once)
# ============================================================
# Runs one Ollama server per GPU, each pinned to a single card, each
# with its own copy of the model loaded. Requests get spread across
# all of them — the closest thing to running the task on several GPUs
# simultaneously without rewriting the pipeline as a distributed job.
#
# Check `nvidia-smi` first and only list GPUs that are actually free —
# from your last check, GPUs 2 and 3 were fully idle; 1, 4, 5, 6 should
# free up once any old/split Ollama process is killed (`pkill ollama`
# on the server first if you had one running manually).

import subprocess, time, os, shutil, platform, requests
from openai import OpenAI

LOCAL_MODEL     = 'qwen2.5:14b'         # ← NON-reasoning (active) — no thinking phase,
                                          #   much faster per call on this hardware
# LOCAL_MODEL   = 'qwen2.5:7b'            # ← even faster still, some quality trade-off
# LOCAL_MODEL   = 'deepseek-r1:14b'       # ← reasoning model, slower but sometimes more accurate
# LOCAL_MODEL   = 'qwen3:14b'             # ← Qwen's own reasoning model — also "thinks" in
                                          #   <think> tags (already stripped below), same speed
                                          #   characteristics as deepseek-r1:14b
# LOCAL_MODEL   = 'deepseek-r1:7b'        # ← smaller/faster reasoning model
OLLAMA_GPU_IDS  = ['2', '3', '6', '7']    # ← one Ollama instance per GPU listed here
OLLAMA_BASE_PORT = 39001                  # ← NOT Ollama's default 11434 — this is a shared
                                          #   server, another user's Ollama already owns
                                          #   11434, so we use a distinct range instead
OLLAMA_NUM_PARALLEL = 2                   # ← concurrent requests PER GPU instance

OLLAMA_HOSTS = [f'http://localhost:{OLLAMA_BASE_PORT + i}' for i in range(len(OLLAMA_GPU_IDS))]

def _run(cmd, **kw):
    """Run a shell command, print its output, and return the CompletedProcess."""
    proc = subprocess.run(cmd, shell=True, capture_output=True, text=True, **kw)
    if proc.stdout: print(proc.stdout)
    if proc.stderr: print(proc.stderr)
    return proc

# ── Confirm GPUs are visible to this notebook (informational only) ──
gpu_check = _run('nvidia-smi --query-gpu=index,name,memory.used,utilization.gpu --format=csv,noheader')
if gpu_check.returncode == 0 and gpu_check.stdout.strip():
    print('GPUs visible:')
    print(gpu_check.stdout)
else:
    print('⚠️  nvidia-smi not found or no GPU visible — Ollama will fall back to CPU (slow).')

# ── Install Ollama (user-space, no sudo needed — good for a shared server) ──
LOCAL_INSTALL_DIR = os.path.expanduser('~/.ollama-local')
_bin_dir = f'{LOCAL_INSTALL_DIR}/bin'
os.makedirs(_bin_dir, exist_ok=True)
if _bin_dir not in os.environ['PATH']:
    os.environ['PATH'] = _bin_dir + os.pathsep + os.environ['PATH']

if shutil.which('ollama') is None:
    arch = platform.machine()
    asset = 'ollama-linux-amd64.tgz' if arch in ('x86_64', 'AMD64') else 'ollama-linux-arm64.tgz'
    print(f'Installing Ollama into {LOCAL_INSTALL_DIR} (no root required)...')
    dl = _run(f'curl -fsSL -o /tmp/ollama.tgz https://ollama.com/download/{asset}')
    if dl.returncode == 0:
        _run(f'tar -xzf /tmp/ollama.tgz -C {LOCAL_INSTALL_DIR}')
    if shutil.which('ollama') is None:
        raise RuntimeError(
            'Ollama install failed (see output above). Common causes:\n'
            '  - This server has no outbound internet access to ollama.com\n'
            '    (check with: curl -I https://ollama.com)\n'
            '  - Try manually in a terminal on the server:\n'
            f'    curl -fsSL -o /tmp/ollama.tgz https://ollama.com/download/{asset}\n'
            f'    tar -xzf /tmp/ollama.tgz -C {LOCAL_INSTALL_DIR}'
        )
    print(f'Ollama installed at: {shutil.which("ollama")}')
else:
    print(f'Ollama already installed at: {shutil.which("ollama")}')

# ── Pre-create the shared model store ONCE — avoids a race where two
#    servers launched at the same instant both try to initialize the same
#    (not-yet-existing) manifests/blobs folders and step on each other ──
_ollama_models_dir = os.path.expanduser('~/.ollama-local/models')
os.makedirs(f'{_ollama_models_dir}/manifests', exist_ok=True)
os.makedirs(f'{_ollama_models_dir}/blobs', exist_ok=True)

# ── Start one Ollama server per GPU (idempotent — skips ones already up) ──
_server_procs = []
for i, gpu_id in enumerate(OLLAMA_GPU_IDS):
    host = OLLAMA_HOSTS[i]
    port = OLLAMA_BASE_PORT + i
    try:
        requests.get(f'{host}/api/tags', timeout=2)
        print(f'GPU {gpu_id}: server already running on port {port}.')
        continue
    except Exception:
        pass
    print(f'GPU {gpu_id}: starting Ollama on port {port}...')
    log = open(f'/tmp/ollama_serve_gpu{gpu_id}.log', 'w')
    env = os.environ.copy()
    env['OLLAMA_MODELS']        = _ollama_models_dir
    env['CUDA_VISIBLE_DEVICES'] = gpu_id
    env['OLLAMA_NUM_PARALLEL']  = str(OLLAMA_NUM_PARALLEL)
    env['OLLAMA_HOST']          = f'127.0.0.1:{port}'
    proc = subprocess.Popen(['ollama', 'serve'], stdout=log, stderr=log, env=env)
    _server_procs.append((gpu_id, proc))
    time.sleep(3)   # stagger launches — avoids the startup race above

# ── Wait for all of them to come up ────────────────────────────
for i, gpu_id in enumerate(OLLAMA_GPU_IDS):
    host = OLLAMA_HOSTS[i]
    for _ in range(15):
        try:
            requests.get(f'{host}/api/tags', timeout=2)
            print(f'GPU {gpu_id} ({host}): up.')
            break
        except Exception:
            time.sleep(2)
    else:
        log_path = f'/tmp/ollama_serve_gpu{gpu_id}.log'
        print(open(log_path).read() if os.path.exists(log_path) else '(no log)')
        raise RuntimeError(f'Ollama server on GPU {gpu_id} did not start — see log above ({log_path}).')

# ── Pull the model on each instance (no-op if already pulled — the tarball
#    is cached on disk, so this is fast after the first GPU) ─────────────
for i, gpu_id in enumerate(OLLAMA_GPU_IDS):
    host = OLLAMA_HOSTS[i]
    print(f'GPU {gpu_id}: pulling {LOCAL_MODEL}...')
    env = os.environ.copy()
    env['OLLAMA_HOST'] = host.replace('http://', '')
    pull = subprocess.run(f'ollama pull {LOCAL_MODEL}', shell=True, capture_output=True, text=True, env=env)
    if pull.returncode != 0:
        print(pull.stdout, pull.stderr)
        raise RuntimeError(f'Failed to pull {LOCAL_MODEL} on GPU {gpu_id}.')

# ── One OpenAI-compatible client per GPU instance — call_llm round-robins
#    across these so requests actually spread across all the GPUs ────────
local_clients = [OpenAI(base_url=f'{host}/v1', api_key='ollama') for host in OLLAMA_HOSTS]

print(f'\nLocal model ready: {LOCAL_MODEL} on {len(local_clients)} GPU(s): {OLLAMA_GPU_IDS}')
# Out:
# 0, NVIDIA GeForce GTX 1080 Ti, 3582 MiB, 0 %
# 1, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 2, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 3, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 4, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 5, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 6, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 7, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
#
# GPUs visible:
# 0, NVIDIA GeForce GTX 1080 Ti, 3582 MiB, 0 %
# 1, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 2, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 3, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 4, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 5, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 6, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
# 7, NVIDIA GeForce GTX 1080 Ti, 4 MiB, 0 %
#
# Ollama already installed at: /usr/local/bin/ollama
# GPU 2: starting Ollama on port 39001...
# GPU 3: starting Ollama on port 39002...
# GPU 6: starting Ollama on port 39003...
# GPU 7: starting Ollama on port 39004...
# GPU 2 (http://localhost:39001): up.
# GPU 3 (http://localhost:39002): up.
# GPU 6 (http://localhost:39003): up.
# GPU 7 (http://localhost:39004): up.
# GPU 2: pulling qwen2.5:14b...
# GPU 3: pulling qwen2.5:14b...
# GPU 6: pulling qwen2.5:14b...
# GPU 7: pulling qwen2.5:14b...
#
# Local model ready: qwen2.5:14b on 4 GPU(s): ['2', '3', '6', '7']

# %%
# ============================================================
# CELL 4 — Load & prepare data (LIVE from GitHub — all bug issues)
# ============================================================
# Pulls every issue labeled "type:bug" (open + closed) directly from
# github.com/tianocore/edk2, instead of the old static CSV export.
#
# Ground truth (priority / first assignee for a small curated set, plus
# 4 known-invalid and 2 known-duplicate pairs) is preserved separately
# below and used ONLY to keep evaluation metrics for the issues we
# actually know the answer for. Everything else is pure production
# inference — there's no ground truth to check it against.

import pandas as pd, re, os, time, requests

pipeline_start_time = time.time()   # total pipeline (setup + inference)
setup_start_time    = time.time()   # setup only
print(f'Pipeline started at: {time.strftime("%Y-%m-%d %H:%M:%S")} (GitHub API fetch)')

def _clean(text):
    text = re.sub(r'https?://\S+', '<URL>', text or '')
    return re.sub(r'\s+', ' ', text).strip()

# ── Optional cap for testing — None = process every fetched issue ────
MAX_ISSUES = None   # ← e.g. set to 50 while testing, None for the full run

# ── Fetch ALL issues labeled type:bug (open + closed) ─────────────────
REPO = 'tianocore/edk2'
_gh_headers = {'Accept': 'application/vnd.github+json'}
if GITHUB_TOKEN:
    _gh_headers['Authorization'] = f'Bearer {GITHUB_TOKEN}'

def fetch_all_bug_issues(repo=REPO, label='type:bug', per_page=100):
    issues, page = [], 1
    while True:
        resp = requests.get(
            f'https://api.github.com/repos/{repo}/issues',
            headers=_gh_headers,
            params={'labels': label, 'state': 'all', 'per_page': per_page, 'page': page},
        )
        if resp.status_code != 200:
            print(f'  [warn] GitHub API returned {resp.status_code} on page {page}: {resp.text[:200]}')
            break
        batch = resp.json()
        if not batch:
            break
        # The /issues endpoint also returns PRs — filter those out
        issues.extend([it for it in batch if 'pull_request' not in it])
        print(f'  page {page}: +{len(batch)} (total {len(issues)})')
        if len(batch) < per_page:
            break
        page += 1
        time.sleep(0.15)  # be polite to the API
    return issues

print(f'\nFetching all "type:bug" issues from {REPO} (open + closed)...')
_raw_issues = fetch_all_bug_issues()
print(f'Fetched {len(_raw_issues)} issues total.')

def build_issue_from_gh(it):
    labels   = [l['name'] if isinstance(l, dict) else l for l in it.get('labels', [])]
    package  = (next((l.split(':', 1)[1] for l in labels if l.lower().startswith('package:')), None)
                or next((l for l in labels if re.fullmatch(r'\w+Pkg', l)), '-'))
    priority = next((l.split(':', 1)[1].lower() for l in labels if l.lower().startswith('priority:')), '-')
    assignees = it.get('assignees') or []
    return {
        'id'               : str(it['number']),
        'title'            : str(it.get('title') or ''),
        'body'             : _clean(it.get('body') or ''),
        'package'          : package,
        'type'             : 'bug',
        'priority'         : priority,
        'comments'         : int(it.get('comments', 0)),
        'state'            : it.get('state', ''),
        'labels'           : labels,
        'current_assignee' : assignees[0]['login'] if assignees else None,
        'true_assignee'    : None,   # filled in below only where we have curated GT
        'text'             : _clean(f"Title: {it.get('title','')}\n\nDescription: {it.get('body','')}"),
    }

all_issues = [build_issue_from_gh(it) for it in _raw_issues]
_by_id     = {i['id']: i for i in all_issues}
print(f'\nGitHub bug issues loaded: {len(all_issues)}')

# ── Ground truth — sourced directly from labels already on the issues ──
# The repo tags issues with `state:invalid`, `state:duplicate`, and
# `priority:low|medium|high` across the WHOLE tracker, not just a curated
# subset — so we use those directly rather than a small hardcoded list.
# (`priority` is already parsed onto every issue in build_issue_from_gh.)

def _has_label(issue, label):
    return any(l.lower() == label for l in issue['labels'])

# Invalid detection GT: True for anything actually tagged state:invalid.
# For confident negatives, use issues with a known first assignee (CSV) —
# those were triaged and worked on, so they're definitely not invalid.
GT_TRUE_INVALID = {i['id']: True for i in all_issues if _has_label(i, 'state:invalid')}

# Duplicate detection GT: True for anything tagged state:duplicate.
GT_TRUE_DUP = {i['id']: True for i in all_issues if _has_label(i, 'state:duplicate')}

# Legacy exact pairs — kept only for the "did it name the right partner"
# bonus check in the Duplicate task; state:duplicate alone doesn't tell us
# WHICH issue something duplicates, only that it does.
GT_PAIRS_FULL = [{'11791', '11790'}, {'11948', '11462'}]

# Priority / first-assignee ground truth for the small curated set (still
# the only source we have for "who actually got assigned this bug").
GT_PRIORITY = {}   # issue_id -> curated true priority (from CSV)
GT_ASSIGNEE = {}   # issue_id -> curated true first assignee (from CSV)

if GITHUB_CSV:
    _df_gt = pd.read_csv(GITHUB_CSV)
    _df_gt_labeled = _df_gt[_df_gt['First Assignee'].notna()]
    for _, r in _df_gt_labeled.iterrows():
        iid = str(int(r['Issue Number']))
        GT_ASSIGNEE[iid] = str(r['First Assignee'])
        if pd.notna(r.get('priority')):
            GT_PRIORITY[iid] = str(r['priority']).lower()
    print(f'\nGround-truth reference loaded: {len(GT_ASSIGNEE)} assignees, {len(GT_PRIORITY)} priorities')
else:
    print('\nNo ground-truth CSV — assignment task will run as pure inference (no eval).')

# ── Make sure every GT issue is actually present, fetching individually if a
#    label mismatch means the bulk fetch missed it ─────────────────────────
_gt_ids_needed = set(GT_ASSIGNEE) | set(GT_TRUE_INVALID) | set(GT_TRUE_DUP)
for iid in _gt_ids_needed:
    if iid not in _by_id:
        r = requests.get(f'https://api.github.com/repos/{REPO}/issues/{iid}', headers=_gh_headers)
        if r.status_code == 200:
            issue = build_issue_from_gh(r.json())
            all_issues.append(issue)
            _by_id[iid] = issue
            print(f'  [info] fetched GT issue #{iid} individually (missed by the bulk label query)')
        else:
            print(f'  [warn] could not fetch GT issue #{iid} (status {r.status_code})')

# Attach GT priority/assignee onto the matching issue objects
for iid, assignee in GT_ASSIGNEE.items():
    if iid in _by_id:
        _by_id[iid]['true_assignee'] = assignee
for iid, pri in GT_PRIORITY.items():
    if iid in _by_id:
        _by_id[iid]['priority'] = pri

# `labeled_issues` = historical eval set: every issue with a known first assignee.
# These also serve as confident NEGATIVES for invalid/duplicate — a bug that
# was actually triaged and assigned is definitely not invalid or a duplicate.
labeled_issues = [i for i in all_issues if i['id'] in GT_ASSIGNEE]
for i in labeled_issues:
    GT_TRUE_INVALID.setdefault(i['id'], False)
    GT_TRUE_DUP.setdefault(i['id'], False)

print(f'\nKnown-ground-truth issues (assignment eval): {len(labeled_issues)}')

KNOWN_ASSIGNEES = sorted(set(GT_ASSIGNEE.values()))
print(f'Known assignees ({len(KNOWN_ASSIGNEES)}): {KNOWN_ASSIGNEES}')

print(f'\nInvalid GT   : {sum(GT_TRUE_INVALID.values())} true / {len(GT_TRUE_INVALID)} labeled total')
print(f'Duplicate GT : {sum(GT_TRUE_DUP.values())} true / {len(GT_TRUE_DUP)} labeled total')

# Priority GT now comes from the live `priority:` labels already parsed onto
# every fetched issue (not just the curated 36) — CSV values above override
# where both exist, but most priority GT will come straight from GitHub.
issues_with_priority = [i for i in all_issues if i.get('priority', '-').lower() in ('low', 'medium', 'high')]
print(f'Priority GT  : {len(issues_with_priority)} issues have a priority: label')

# ── Target set for all 4 tasks — every fetched issue, optionally capped ──
TARGET_ISSUES = all_issues if MAX_ISSUES is None else all_issues[:MAX_ISSUES]
print(f'\nTARGET_ISSUES for this run: {len(TARGET_ISSUES)}'
      + ('' if MAX_ISSUES is None else f'  (capped at MAX_ISSUES={MAX_ISSUES})'))
# Out:
# Pipeline started at: 2026-08-12 08:56:13 (GitHub API fetch)
#
# Fetching all "type:bug" issues from tianocore/edk2 (open + closed)...
#   page 1: +100 (total 99)
#   page 2: +100 (total 199)
#   page 3: +100 (total 299)
#   page 4: +100 (total 399)
#   page 5: +100 (total 499)
#   page 6: +100 (total 599)
#   page 7: +100 (total 699)
#   page 8: +100 (total 799)
#   page 9: +100 (total 899)
#   page 10: +100 (total 999)
#   page 11: +100 (total 1099)
#   page 12: +100 (total 1199)
#   page 13: +100 (total 1299)
#   page 14: +100 (total 1399)
#   page 15: +100 (total 1499)
#   page 16: +100 (total 1599)
#   page 17: +100 (total 1699)
#   page 18: +100 (total 1799)
#   page 19: +100 (total 1899)
#   page 20: +100 (total 1999)
#   page 21: +100 (total 2099)
#   page 22: +100 (total 2199)
#   page 23: +100 (total 2299)
#   page 24: +100 (total 2399)
#   page 25: +100 (total 2499)
#   page 26: +100 (total 2599)
#   page 27: +100 (total 2699)
#   page 28: +100 (total 2799)
#   page 29: +100 (total 2899)
#   page 30: +100 (total 2999)
#   page 31: +100 (total 3099)
#   page 32: +100 (total 3199)
#   page 33: +100 (total 3299)
#   page 34: +100 (total 3399)
#   page 35: +100 (total 3499)
#   page 36: +47 (total 3546)
# Fetched 3546 issues total.
#
# GitHub bug issues loaded: 3546
#
# Ground-truth reference loaded: 37 assignees, 37 priorities
#
# Known-ground-truth issues (assignment eval): 37
# Known assignees (29): ['AndreasBBS', 'AshrafAliS', 'BritChesley', 'Damien-Chen', 'EricGao2015', 'HunterChang030', 'NingFengGit', 'SaloniKasbekar', 'Vogtinator', 'YangGangUEFI', 'ardbiesheuvel', 'bexcran', 'deeglaze', 'jxu023', 'lgao4', 'liyi77', 'makubacki', 'mdkinney', 'mikebeaton', 'os-d', 'philnoh2', 'praravin', 'praveensankarn', 'r1chard-lyu', 'vit9696', 'wenbhou', 'yechao-w', 'zevorn', 'zhurui22']
#
# Invalid GT   : 134 true / 171 labeled total
# Duplicate GT : 80 true / 117 labeled total
# Priority GT  : 3545 issues have a priority: label
#
# TARGET_ISSUES for this run: 3546

# %%
# ============================================================
# CELL 5 — Ingest XML corpus (only needed for System B / RAG)
# Skipped automatically if USE_RAG = False
# ============================================================
if not USE_RAG:
    print("⏭️  Skipping XML ingestion (USE_RAG=False — System A active)")
    xml_bugs             = []
    xml_invalid_examples = []
    xml_valid_examples   = []
    xml_dup_pairs        = {}
else:
    # ============================================================
    # CELL 5 — Ingest XML corpus
    # ============================================================
    import xml.etree.ElementTree as ET

    def _xml_body(bug_el):
        bodies = []
        for ld in bug_el.findall('long_desc'):
            t = ld.find('thetext')
            if t is not None and t.text:
                bodies.append(t.text.strip())
            if len(bodies) >= 3:
                break
        return '\n\n'.join(bodies)

    def load_xml_corpus(xml_paths):
        bugs = []
        for path in xml_paths:
            if not os.path.exists(path):
                print(f'  [skip] {path} not found')
                continue
            tree = ET.parse(path)
            root = tree.getroot()
            for bug_el in root.findall('bug'):
                def t(tag):
                    n = bug_el.find(tag)
                    return (n.text or '').strip() if n is not None else ''
                title      = t('short_desc')
                body       = _xml_body(bug_el)
                resolution = t('resolution')
                dup_node   = bug_el.find('dup_id')
                dup_id     = dup_node.text.strip() if dup_node is not None and dup_node.text else None
                bugs.append(dict(
                    id         = t('bug_id'),
                    title      = title,
                    body       = body,
                    package    = t('cf_package'),
                    component  = t('component'),
                    priority   = t('priority'),
                    resolution = resolution,
                    dup_id     = dup_id,
                    text       = _clean(f'Title: {title}\n\nDescription: {body}'),
                ))
        print(f'[ingest] XML corpus: {len(bugs):,} bugs from {len(xml_paths)} files')
        return bugs

    xml_bugs = load_xml_corpus(XML_FILES)

    # Separate invalid/valid XML examples for invalid detection
    xml_invalid_examples = [b for b in xml_bugs if b.get('resolution','').upper() == 'INVALID']
    xml_valid_examples   = [b for b in xml_bugs if b.get('resolution','').upper() not in ('INVALID','')]
    print(f'XML invalid examples : {len(xml_invalid_examples)}')
    print(f'XML valid examples   : {len(xml_valid_examples)}')

    # XML duplicate pairs
    xml_dup_pairs = {b['id']: b['dup_id'] for b in xml_bugs if b.get('dup_id')}
    print(f'XML duplicate pairs  : {len(xml_dup_pairs)}')
# Out:
# ⏭️  Skipping XML ingestion (USE_RAG=False — System A active)

# %%
# ============================================================
# CELL 6 — Build retrievers (ChromaDB + BM25)
# Run once — indexes persist to Drive
# ============================================================
import torch
import chromadb
from chromadb import EmbeddingFunction, Documents, Embeddings
from sentence_transformers import SentenceTransformer
from rank_bm25 import BM25Okapi
from tqdm.notebook import tqdm

EMBED_MODEL = 'BAAI/bge-base-en-v1.5'
EMBED_BATCH = 64
RRF_K       = 60

def get_device():
    if torch.cuda.is_available():   return 'cuda'
    if hasattr(torch.backends,'mps') and torch.backends.mps.is_available(): return 'mps'
    return 'cpu'

def tokenise(text):
    text = re.sub(r'[^a-zA-Z0-9_]', ' ', (text or '').lower())
    return [t for t in text.split() if len(t) > 1]

def rrf(ranked_a, ranked_b, k=RRF_K):
    scores = {}
    for rank, doc_id in enumerate(ranked_a, 1):
        scores[doc_id] = scores.get(doc_id, 0.0) + 1.0 / (k + rank)
    for rank, doc_id in enumerate(ranked_b, 1):
        scores[doc_id] = scores.get(doc_id, 0.0) + 1.0 / (k + rank)
    return sorted(scores, key=scores.__getitem__, reverse=True)

class BGEEmbeddingFunction(EmbeddingFunction):
    def __init__(self):
        device = get_device()
        print(f'[retriever] Loading {EMBED_MODEL} on {device}...')
        self._model = SentenceTransformer(EMBED_MODEL, device=device)
        print('[retriever] Model loaded')
    def __call__(self, input: Documents) -> Embeddings:
        return self._model.encode(
            list(input), batch_size=EMBED_BATCH,
            normalize_embeddings=True, show_progress_bar=False,
        ).tolist()

_embed_fn = BGEEmbeddingFunction()
_chroma   = chromadb.PersistentClient(path=CHROMA_DIR)

def _get_or_create(name):
    return _chroma.get_or_create_collection(
        name, embedding_function=_embed_fn,
        metadata={'hnsw:space': 'cosine'},
    )

def _index_docs(col, docs, label, force=False):
    if col.count() > 0 and not force:
        print(f'[retriever] {label}: {col.count():,} docs already indexed')
        return
    print(f'[retriever] Indexing {len(docs):,} {label} docs...')
    for i in tqdm(range(0, len(docs), EMBED_BATCH), desc=label):
        batch = docs[i:i+EMBED_BATCH]
        col.add(
            ids       = [d['id'] for d in batch],
            documents = [d['text'] for d in batch],
            metadatas = [{'title': d['title'][:500],
                          'package': str(d.get('package','') or ''),
                          'priority': str(d.get('priority','') or ''),
                          'body': str(d.get('body','') or '')[:300]} for d in batch],
        )
    print(f'[retriever] {label}: done ({col.count():,} docs)')

def _hybrid_search(query_text, col, bm25, bm25_ids, index, exclude_id, k):
    if col.count() == 0:
        return []
    fetch     = min(k * 4, col.count())
    dense_res = col.query(query_texts=[query_text], n_results=fetch, include=['distances'])
    dense_ids = [i for i in dense_res['ids'][0] if i != exclude_id]
    if bm25 is None or not bm25_ids:
        return [index[i] for i in dense_ids[:k] if i in index]
    scores    = bm25.get_scores(tokenise(query_text))
    sparse    = [bm25_ids[i]
                 for i in sorted(range(len(scores)), key=lambda x:-scores[x])
                 if bm25_ids[i] != exclude_id][:fetch]
    merged = rrf(dense_ids, sparse)[:k]
    return [index[i] for i in merged if i in index]

# ── XML collection (for duplicate + invalid RAG) ──────────────
if USE_RAG:
    _xml_col    = _get_or_create('xml_corpus_integrated')
    _index_docs(_xml_col, xml_bugs, 'XML corpus')
    _xml_by_id  = {b['id']: b for b in xml_bugs}
    _xml_bm25   = BM25Okapi([tokenise(b['text']) for b in xml_bugs]) if xml_bugs else None
    _xml_ids    = [b['id'] for b in xml_bugs]
else:
    _xml_col   = None
    _xml_by_id = {}
    _xml_bm25  = None
    _xml_ids   = []
    print('⏭️  XML collection skipped (USE_RAG=False)')

# ── GitHub issues collection (for duplicate candidate search) ─
_gh_col     = _get_or_create('github_issues_integrated')
_index_docs(_gh_col, all_issues, 'GitHub issues')
_gh_by_id   = {i['id']: i for i in all_issues}
_gh_bm25    = BM25Okapi([tokenise(i['text']) for i in all_issues]) if all_issues else None
_gh_ids     = [i['id'] for i in all_issues]

# ── Labeled issues collection (for bug assignment RAG) ────────
_lab_col    = _get_or_create('labeled_issues_integrated')
_index_docs(_lab_col, labeled_issues, 'Labeled issues')
_lab_by_id  = {i['id']: i for i in labeled_issues}
_lab_bm25   = BM25Okapi([tokenise(i['text']) for i in labeled_issues]) if labeled_issues else None
_lab_ids    = [i['id'] for i in labeled_issues]

# ── Bugzilla collection (for priority RAG) ────────────────────
if USE_RAG:
    _bz_col   = _get_or_create('bugzilla_priority_integrated')
    _bz_docs  = [{
        'id': b['id'], 'title': b['title'], 'body': b.get('body',''),
        'package': b.get('package',''), 'priority': b.get('priority',''),
        'text': _clean(f"Title: {b['title']}\n\nDescription: {b.get('body','')}")
    } for b in xml_bugs if b.get('priority','').lower() in ('low','medium','high')]
    _index_docs(_bz_col, _bz_docs, 'Bugzilla priority')
    _bz_bm25  = BM25Okapi([tokenise(d['text']) for d in _bz_docs]) if _bz_docs else None
    _bz_ids   = [d['id'] for d in _bz_docs]
    _bz_by_id = {d['id']: d for d in _bz_docs}
else:
    _bz_col   = None
    _bz_docs  = []
    _bz_bm25  = None
    _bz_ids   = []
    _bz_by_id = {}
    print('⏭️  Bugzilla collection skipped (USE_RAG=False)')

# ── Helper retrieval functions ─────────────────────────────────
def get_xml_context(issue, k=3):
    return _hybrid_search(issue['text'], _xml_col, _xml_bm25, _xml_ids, _xml_by_id, None, k)

def get_xml_dup_pairs(issue, k=3):
    similar = get_xml_context(issue, k=k)
    pairs = []
    for bug in similar:
        dup_id = bug.get('dup_id')
        pairs.append((bug, _xml_by_id.get(dup_id) if dup_id else None))
    return pairs

def get_dup_candidates(issue, k=5):
    return _hybrid_search(issue['text'], _gh_col, _gh_bm25, _gh_ids, _gh_by_id, issue['id'], k)

def get_similar_labeled(issue, k=5):
    return _hybrid_search(issue['text'], _lab_col, _lab_bm25, _lab_ids, _lab_by_id, issue['id'], k)

def get_bz_priority_context(issue, k=5):
    return _hybrid_search(issue['text'], _bz_col, _bz_bm25, _bz_ids, _bz_by_id, None, k)

print('\nAll retrievers ready.')


# ── Setup time ───────────────────────────────────────────────
setup_elapsed = time.time() - setup_start_time
inference_start_time = time.time()  # inference starts after retrievers are built
print(f'\n[SETUP] Runtime: {setup_elapsed:.1f}s ({setup_elapsed/60:.2f} min)')
print(f'[SETUP] Includes: CSV load, XML ingestion, ChromaDB + BM25 index build')
# Out:
# /home/nsiavash/anaconda3/lib/python3.12/site-packages/torch/cuda/__init__.py:188: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12020). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /__w/pytorch/pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [retriever] Loading BAAI/bge-base-en-v1.5 on cpu...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [retriever] Model loaded
# ⏭️  XML collection skipped (USE_RAG=False)
# [retriever] GitHub issues: 3,546 docs already indexed
# [retriever] Indexing 37 Labeled issues docs...
# Labeled issues:   0%|          | 0/1 [00:00<?, ?it/s]
# [retriever] Labeled issues: done (37 docs)
# ⏭️  Bugzilla collection skipped (USE_RAG=False)
#
# All retrievers ready.
#
# [SETUP] Runtime: 48.8s (0.81 min)
# [SETUP] Includes: CSV load, XML ingestion, ChromaDB + BM25 index build

# %%
# ============================================================
# CELL 7 — API clients & unified LLM caller
# ============================================================
import json, time, re
from openai import OpenAI

try:
    import anthropic
except ImportError:
    # !pip install -q anthropic
    import anthropic

_openai_headers = {}
if OPENAI_ORG_ID:     _openai_headers['OpenAI-Organization'] = OPENAI_ORG_ID
if OPENAI_PROJECT_ID: _openai_headers['OpenAI-Project']      = OPENAI_PROJECT_ID

openai_client    = OpenAI(api_key=OPENAI_API_KEY, default_headers=_openai_headers)
anthropic_client = anthropic.Anthropic(api_key=ANTHROPIC_API_KEY) if ANTHROPIC_API_KEY else None

print(f"OpenAI client   : set")
print(f"Anthropic client: {'set' if anthropic_client else 'not set (no key)'}")

def _parse_json(raw):
    """Extract JSON from raw LLM output — handles preamble, fences, bad escapes."""
    raw = re.sub(r'```(?:json)?\s*', '', raw)
    raw = re.sub(r'```', '', raw).strip()
    candidates = []
    depth, start = 0, None
    for idx, ch in enumerate(raw):
        if ch == '{':
            if depth == 0: start = idx
            depth += 1
        elif ch == '}':
            depth -= 1
            if depth == 0 and start is not None:
                candidates.append(raw[start:idx+1]); start = None
    for blob in reversed(candidates):
        blob = re.sub(r'\\(?!["\\/bfnrtu])', r'\\\\', blob)
        try:    return json.loads(blob)
        except: continue
    raise ValueError(f'Could not parse JSON from: {raw[:200]}')

# ── Round-robin across GPU instances so concurrent requests spread out ──
import itertools, threading
_client_cycle = itertools.cycle(range(len(local_clients))) if 'local_clients' in dir() else None
_client_lock  = threading.Lock()

def _next_local_client():
    with _client_lock:
        return local_clients[next(_client_cycle)]

def call_llm(system_prompt, user_content, model, max_tokens=512):
    """Route to OpenAI Chat / Responses API / Anthropic / local Ollama based on model name."""
    is_claude = model.startswith('claude')
    is_local  = model == LOCAL_MODEL or model.startswith('deepseek') or model.startswith('qwen')
    use_resp  = (not is_local) and any(model.startswith(m) for m in _RESPONSES_API_MODELS)

    for attempt in range(3):
        try:
            if is_claude:
                resp = anthropic_client.messages.create(
                    model=model, max_tokens=max_tokens,
                    system=system_prompt,
                    messages=[{'role': 'user', 'content': user_content}],
                )
                raw = resp.content[0].text
            elif is_local:
                # DeepSeek-R1 is a reasoning model — it "thinks" before answering,
                # so give it more headroom than the API models get.
                resp = _next_local_client().chat.completions.create(
                    model=model, temperature=0.0, max_tokens=max(max_tokens, 2048),
                    messages=[
                        {'role': 'system', 'content': system_prompt},
                        {'role': 'user',   'content': user_content},
                    ],
                )
                raw = resp.choices[0].message.content
                # Strip <think>...</think> chain-of-thought so JSON parsing only
                # sees the final answer.
                raw = re.sub(r'<think>.*?</think>', '', raw, flags=re.DOTALL).strip()
            elif use_resp:
                full_input = system_prompt + '\n\n' + user_content
                resp = openai_client.responses.create(
                    model=model, input=full_input,
                    extra_headers=_openai_headers,
                )
                raw = resp.output_text
            else:
                resp = openai_client.chat.completions.create(
                    model=model, temperature=0.0, max_tokens=max_tokens,
                    messages=[
                        {'role': 'system', 'content': system_prompt},
                        {'role': 'user',   'content': user_content},
                    ],
                    extra_headers=_openai_headers,
                )
                raw = resp.choices[0].message.content
            return _parse_json(raw)
        except Exception as e:
            print(f'  [attempt {attempt+1}] {type(e).__name__}: {e}')
            if attempt < 2: time.sleep(2 ** attempt)
    return None

# ── Concurrent runner ─────────────────────────────────────────
# Ollama can serve multiple requests at once (set via OLLAMA_NUM_PARALLEL
# when you start `ollama serve`) — the sequential loops below were only
# using one request at a time, leaving GPU compute idle. This runs `fn`
# over `items` with a small thread pool and returns results in the same
# order as the input, so the rest of each cell doesn't need to change.
from concurrent.futures import ThreadPoolExecutor, as_completed

# Total useful concurrency ≈ (GPU instances) × (parallel requests per instance)
MAX_WORKERS = (len(local_clients) * OLLAMA_NUM_PARALLEL) if 'local_clients' in dir() else 4

def run_concurrent(fn, items, max_workers=MAX_WORKERS, desc=''):
    results = [None] * len(items)
    with ThreadPoolExecutor(max_workers=max_workers) as pool:
        futures = {pool.submit(fn, item): i for i, item in enumerate(items)}
        for f in tqdm(as_completed(futures), total=len(futures), desc=desc):
            i = futures[f]
            try:
                results[i] = f.result()
            except Exception as e:
                results[i] = e
    return results

print('call_llm ready.')
# Out:
# OpenAI client   : set
# Anthropic client: not set (no key)
# call_llm ready.

# %% [markdown]
# ## Task 1 — Invalid Issue Detection
#
# Best model: `claude-sonnet-4-6` System A
# Ground truth: 4 confirmed invalids (#10579, #11258, #11453, #11480)

# %%
invalid_start = time.time()
print(f'[INVALID] Starting...')

# ============================================================
# CELL 8 — Invalid Issue Detection
# Best model: claude-sonnet-4-6 System A
# ============================================================
import csv, random
from tqdm.notebook import tqdm

random.seed(42)

# ── Active model for invalid detection ───────────────────────
INVALID_MODEL  = LOCAL_MODEL           # ← local DeepSeek-R1-Distill-Qwen (active)
# INVALID_MODEL = 'claude-sonnet-4-6'    # previous best model — highest Mac-F1 on 4-GT
# INVALID_MODEL = 'gpt-4o-mini'
# INVALID_MODEL = 'gpt-4o'
# INVALID_MODEL = 'gpt-4.1-mini'
# INVALID_MODEL = 'gpt-4.1'
# INVALID_MODEL = 'gpt-5.4-mini'
# INVALID_MODEL = 'gpt-5.4'        # ← best for 1-GT setup (System B)
# INVALID_MODEL = 'gpt-5.5'
# INVALID_MODEL = 'claude-haiku-4-5'
# INVALID_MODEL = 'claude-opus-4-7'

INVALID_SYSTEM = 'A'   # ← best system (active)
# INVALID_SYSTEM = 'B'
XML_CONTEXT_K  = 3

# ── Mask state to prevent label leakage ──────────────────────
# (kept from the original design — harmless no-op now that state is just
#  GitHub's open/closed rather than a Bugzilla-style "invalid" resolution)
def mask_state(state):
    return '' if str(state).strip().lower() == 'invalid' else state

invalid_test_issues = [{**issue, 'state': mask_state(issue['state'])} for issue in TARGET_ISSUES]

# ── Few-shot examples ─────────────────────────────────────────
fewshot_invalid = random.sample(xml_invalid_examples, min(4, len(xml_invalid_examples)))
fewshot_valid   = random.sample(xml_valid_examples,   min(4, len(xml_valid_examples)))

def build_invalid_fewshot():
    block = "EXAMPLES FROM THIS PROJECT'S HISTORY:\n"
    for b in fewshot_invalid:
        block += f"\nTitle      : {b['title']}\nPackage    : {b.get('package','-')}\nResolution : INVALID\n"
    for b in fewshot_valid:
        block += f"\nTitle      : {b['title']}\nPackage    : {b.get('package','-')}\nResolution : VALID\n"
    return block

_INVALID_SYS = """You are an experienced EDK II firmware project maintainer.

Decide whether a GitHub issue is VALID or INVALID for the EDK II project tracker.

An issue is INVALID if:
- It is spam or completely unrelated to firmware development
  (e.g. printer support, social media, password reset, unrelated software)
- It is a general usage question, not a bug report or feature request
- It describes something that works as designed — the reporter misunderstood the behavior
- It does not contain enough information to reproduce or investigate

An issue is VALID if:
- It is a genuine bug report with a reproducible problem
- It is a legitimate feature request for EDK II
- It describes a real security vulnerability or build failure
- It has enough information to investigate
- It relates to EDK II build infrastructure such as build tools, compilers, or linkers
- It relates to EDK II coding style enforcement tools
- It involves any EDK II package, driver, protocol, or firmware component
- When in doubt, treat the issue as VALID

{fewshot}

Now classify the following issue.
Respond with ONLY valid JSON:
{{
  "is_invalid": <bool>,
  "confidence": <float 0.0-1.0>,
  "reason"    : "<one sentence>"
}}"""

_INVALID_SYS_B = _INVALID_SYS + """

Use the following similar historical bugs as additional context:
{xml_context}"""

def fmt_issue_invalid(issue):
    return (f"Title   : {issue['title']}\n"
            f"Package : {issue.get('package','-')}\n"
            f"Type    : {issue.get('type','-')}\n"
            f"Comments: {issue.get('comments',0)}\n"
            f"State   : {issue.get('state','')}")

def predict_invalid(issue, model=INVALID_MODEL, system=INVALID_SYSTEM):
    fewshot = build_invalid_fewshot()
    if system == 'A':
        sys_prompt = _INVALID_SYS.format(fewshot=fewshot)
    else:
        similar   = get_xml_context(issue, k=XML_CONTEXT_K)
        xml_block = '\n'.join(
            f"- {b['title']} [{b.get('package','-')}] → {b.get('resolution','')}"
            for b in similar
        )
        sys_prompt = _INVALID_SYS_B.format(fewshot=fewshot, xml_context=xml_block)
    user = "ISSUE TO CLASSIFY:\n" + fmt_issue_invalid(issue)
    result = call_llm(sys_prompt, user, model, max_tokens=200)
    if result is None:
        return {'is_invalid': False, 'confidence': 0.0, 'reason': 'error'}
    result['is_invalid'] = bool(result.get('is_invalid', False))
    return result

# ── Run invalid detection ─────────────────────────────────────
print(f"\nRunning invalid detection — model: {INVALID_MODEL}, system: {INVALID_SYSTEM}")
print(f"Issues to process: {len(invalid_test_issues)}")

path_inv_csv = f'{RESULTS_DIR}/invalid_{INVALID_SYSTEM}_{INVALID_MODEL.replace(".","_")}.csv'

def _invalid_worker(issue):
    pred = predict_invalid(issue)
    pred.update({
        'model'       : INVALID_MODEL,
        'system'      : INVALID_SYSTEM,
        'issue_id'    : issue['id'],
        'title'       : issue['title'],
        'package'     : issue['package'],
    })
    return pred

_raw = run_concurrent(_invalid_worker, invalid_test_issues, desc=f'Invalid | {INVALID_MODEL}')
invalid_results = []
for issue, r in zip(invalid_test_issues, _raw):
    if isinstance(r, Exception):
        print(f"  Skipped #{issue['id']}: {r}")
    else:
        invalid_results.append(r)

# Save CSV
keys = ['model','system','issue_id','title','package','is_invalid','confidence','reason']
with open(path_inv_csv, 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=keys, extrasaction='ignore')
    writer.writeheader(); writer.writerows(invalid_results)

n_flagged = sum(1 for r in invalid_results if r['is_invalid'])
print(f"\nFlagged as invalid: {n_flagged}/{len(invalid_results)}")
print(f"Saved → {path_inv_csv}")
invalid_elapsed = time.time() - invalid_start
print(f'[INVALID] Runtime: {invalid_elapsed:.1f}s ({invalid_elapsed/60:.2f} min)')

# ── Evaluation (only on issues with known ground truth) ──────
# GT_TRUE_INVALID comes straight from the state:invalid label across the
# whole tracker (plus labeled_issues as confident negatives) — see CELL 4.
eval_results = [r for r in invalid_results if r['issue_id'] in GT_TRUE_INVALID]
n  = len(eval_results)
if n:
    y_true = [GT_TRUE_INVALID[r['issue_id']] for r in eval_results]
    y_pred = [bool(r['is_invalid']) for r in eval_results]
    TP = sum(1 for t, p in zip(y_true, y_pred) if t and p)
    FP = sum(1 for t, p in zip(y_true, y_pred) if not t and p)
    TN = sum(1 for t, p in zip(y_true, y_pred) if not t and not p)
    FN = sum(1 for t, p in zip(y_true, y_pred) if t and not p)

    prec_pos = TP/(TP+FP) if (TP+FP)>0 else 0.0
    rec_pos  = TP/(TP+FN) if (TP+FN)>0 else 0.0
    f1_pos   = 2*prec_pos*rec_pos/(prec_pos+rec_pos) if (prec_pos+rec_pos)>0 else 0.0
    prec_neg = TN/(TN+FN) if (TN+FN)>0 else 0.0
    rec_neg  = TN/(TN+FP) if (TN+FP)>0 else 0.0
    f1_neg   = 2*prec_neg*rec_neg/(prec_neg+rec_neg) if (prec_neg+rec_neg)>0 else 0.0
    mac_f1   = (f1_pos + f1_neg) / 2
    acc      = (TP + TN) / n

    print(f"\n{'='*60}")
    print(f"  INVALID DETECTION RESULTS ({n} known-ground-truth issues: "
          f"{sum(GT_TRUE_INVALID.values())} invalid + "
          f"{sum(1 for v in GT_TRUE_INVALID.values() if not v)} valid)")
    print(f"{'='*60}")
    print(f"  TP={TP}  FP={FP}  TN={TN}  FN={FN}")
    print(f"  P+={prec_pos:.4f}  R+={rec_pos:.4f}  F1+={f1_pos:.4f}")
    print(f"  P-={prec_neg:.4f}  R-={rec_neg:.4f}  F1-={f1_neg:.4f}")
    print(f"  Mac-F1={mac_f1:.4f}  Acc={acc:.4f}")
    print(f"{'='*60}")
else:
    print("\n  No known-ground-truth issues were in this run — skipping evaluation.")
    TP=FP=TN=FN=0; prec_pos=rec_pos=f1_pos=prec_neg=rec_neg=f1_neg=mac_f1=acc=0.0

# ── Filter valid issues for next tasks ────────────────────────
invalid_issue_ids     = {r['issue_id'] for r in invalid_results if r['is_invalid']}

# ── Save evaluation metrics to CSV ───────────────────────────
import csv as _csv
path_inv_metrics = f'{RESULTS_DIR}/metrics_invalid_{INVALID_SYSTEM}_{INVALID_MODEL.replace(".","_")}.csv'
with open(path_inv_metrics, 'w', newline='') as _f:
    _w = _csv.DictWriter(_f, fieldnames=['model','system','n_issues','TP','FP','TN','FN',
                                          'prec_pos','rec_pos','f1_pos',
                                          'prec_neg','rec_neg','f1_neg',
                                          'mac_p','mac_r','mac_f1',
                                          'wgt_p','wgt_r','wgt_f1','acc'])
    _w.writeheader()
    sup_neg_inv = n
    wgt_p_inv  = prec_neg
    wgt_r_inv  = rec_neg
    wgt_f1_inv = f1_neg
    _w.writerow(dict(model=INVALID_MODEL, system=INVALID_SYSTEM, n_issues=n,
                     TP=TP, FP=FP, TN=TN, FN=FN,
                     prec_pos=round(prec_pos,4), rec_pos=round(rec_pos,4), f1_pos=round(f1_pos,4),
                     prec_neg=round(prec_neg,4), rec_neg=round(rec_neg,4), f1_neg=round(f1_neg,4),
                     mac_p=round((prec_pos+prec_neg)/2,4), mac_r=round((rec_pos+rec_neg)/2,4),
                     mac_f1=round(mac_f1,4),
                     wgt_p=round(wgt_p_inv,4), wgt_r=round(wgt_r_inv,4), wgt_f1=round(wgt_f1_inv,4),
                     acc=round(acc,4)))
print(f"Metrics saved → {path_inv_metrics}")

print(f"\nIssues passing to next task: {len(all_issues)}")
# Out:
# [INVALID] Starting...
#
# Running invalid detection — model: qwen2.5:14b, system: A
# Issues to process: 3546
# Invalid | qwen2.5:14b:   0%|          | 0/3546 [00:00<?, ?it/s]
# Flagged as invalid: 78/3546
# Saved → /home/nsiavash/triage_framework/results/invalid_A_qwen2_5:14b.csv
# [INVALID] Runtime: 2156.8s (35.95 min)
#
# ============================================================
#   INVALID DETECTION RESULTS (171 known-ground-truth issues: 134 invalid + 37 valid)
# ============================================================
#   TP=10  FP=3  TN=34  FN=124
#   P+=0.7692  R+=0.0746  F1+=0.1361
#   P-=0.2152  R-=0.9189  F1-=0.3487
#   Mac-F1=0.2424  Acc=0.2573
# ============================================================
# Metrics saved → /home/nsiavash/triage_framework/results/metrics_invalid_A_qwen2_5:14b.csv
#
# Issues passing to next task: 3546

# %% [markdown]
# ## Task 2 — Duplicate Detection
#
# Best model: `claude-sonnet-4-6` System A (best on both 0-pair and 2-pair GT, FP=0)
#
# **Ground truth pairs:**
# - **#11791** → duplicate of **#11790** (unidirectional)
# - **#11948** ↔ **#11462** (bidirectional)
#
# **Note:** None of these 4 IDs appear in the 37 labeled issues → zero-GT assumption applies for this evaluation set.

# %%
dup_start = time.time()
print(f'[DUPLICATE] Starting...')

# ============================================================
# CELL 9 — Duplicate Detection
# Best model: claude-sonnet-4-6 System A
# ============================================================
from tqdm.notebook import tqdm
import csv

DUP_MODEL      = LOCAL_MODEL           # ← local DeepSeek-R1-Distill-Qwen (active)
# DUP_MODEL    = 'claude-sonnet-4-6'   # previous best model
                                        #   0-pair GT: best on A & B (FP=0)
                                        #   2-pair GT: best on A & B (FP=0, Mac-F1=0.826)
# DUP_MODEL    = 'gpt-4o-mini'         # ← tied best on 2-pair GT System A
# DUP_MODEL    = 'gpt-4o'
# DUP_MODEL    = 'gpt-4.1-mini'
# DUP_MODEL    = 'gpt-4.1'
# DUP_MODEL    = 'gpt-5.4-mini'
# DUP_MODEL    = 'gpt-5.4'
# DUP_MODEL    = 'gpt-5.5'
# DUP_MODEL    = 'claude-haiku-4-5'
# DUP_MODEL    = 'claude-opus-4-7'     # ← tied best on 2-pair GT System A

DUP_SYSTEM     = 'A'   # ← best system (active)
# DUP_SYSTEM   = 'B'
DUP_CANDIDATE_K = 5
XML_DUP_K       = 3

_PROMPT_DUP_A = """Find duplicate GitHub issues.

Given a QUERY ISSUE and a list of CANDIDATE ISSUES, is the query a duplicate of any candidate?

Two issues are duplicates only if they report the exact same bug or request the exact same change.
Same package or similar topic is not enough.
When in doubt return is_duplicate: false.

Respond with ONLY valid JSON:
{{
  "is_duplicate": <bool>,
  "duplicate_of": <issue number as string, or null>,
  "confidence"  : <float 0.0-1.0>,
  "reason"      : "<one sentence>"
}}"""

_PROMPT_DUP_B = """Find duplicate GitHub issues.

You will be given DUPLICATE EXAMPLES from this codebase's history, a QUERY ISSUE, and CANDIDATE ISSUES.

The duplicate examples are real pairs of bugs that were marked as the same issue in this project.
Use them to understand what counts as a duplicate in this specific codebase.

Two GitHub issues are duplicates only if they report the exact same bug or request the exact same change.
Same package or similar topic is not enough.
When in doubt return is_duplicate: false.

Respond with ONLY valid JSON:
{{
  "is_duplicate": <bool>,
  "duplicate_of": <issue number as string, or null>,
  "confidence"  : <float 0.0-1.0>,
  "reason"      : "<one sentence>"
}}"""

def fmt_github_issue(issue):
    return (f"Issue #{issue['id']}\n"
            f"Title  : {issue['title']}\n"
            f"Package: {issue.get('package','-')}")

def fmt_xml_pair(bug, dup_bug):
    r = "--- Example duplicate pair ---\n"
    r += f"Bug A: {bug['title']}\n  {(bug.get('body') or '')[:200]}\n"
    if dup_bug:
        r += f"Bug B (same as A): {dup_bug['title']}\n  {(dup_bug.get('body') or '')[:200]}\n"
    return r

def predict_duplicate(issue, model=DUP_MODEL, system=DUP_SYSTEM):
    candidates = get_dup_candidates(issue, k=DUP_CANDIDATE_K)
    if system == 'A':
        sys_prompt = _PROMPT_DUP_A
        user = "QUERY ISSUE:\n" + fmt_github_issue(issue)
        user += "\n\nCANDIDATE ISSUES:\n"
        for i, c in enumerate(candidates, 1):
            user += f"\n[{i}]\n{fmt_github_issue(c)}\n"
    else:
        xml_pairs = get_xml_dup_pairs(issue, k=XML_DUP_K)
        sys_prompt = _PROMPT_DUP_B
        user = ""
        pairs_with_both = [(a,b) for a,b in xml_pairs if b is not None]
        if pairs_with_both:
            user += "DUPLICATE EXAMPLES FROM THIS CODEBASE:\n"
            for bug, dup_bug in pairs_with_both:
                user += f"\n{fmt_xml_pair(bug, dup_bug)}\n"
            user += "\n---\n\n"
        user += "QUERY ISSUE:\n" + fmt_github_issue(issue)
        user += "\n\nCANDIDATE ISSUES:\n"
        for i, c in enumerate(candidates, 1):
            user += f"\n[{i}]\n{fmt_github_issue(c)}\n"

    result = call_llm(sys_prompt, user, model, max_tokens=1500)
    if result is None:
        return {'is_duplicate': False, 'duplicate_of': None, 'confidence': 0.0}
    return result

# ── Run duplicate detection ───────────────────────────────────
issues_for_dup = TARGET_ISSUES

print(f"\nRunning duplicate detection — model: {DUP_MODEL}, system: {DUP_SYSTEM}")
print(f"Issues to process: {len(issues_for_dup)}")
print(f"Known duplicate pairs: {GT_PAIRS_FULL}")

path_dup_csv = f'{RESULTS_DIR}/dup_{DUP_SYSTEM}_{DUP_MODEL.replace(".","_")}.csv'

def _dup_worker(issue):
    pred = predict_duplicate(issue)
    dup_title = _gh_by_id.get(str(pred.get('duplicate_of') or ''), {}).get('title', '')
    pred.update({
        'model'          : DUP_MODEL,
        'system'         : DUP_SYSTEM,
        'issue_id'       : issue['id'],
        'title'          : issue['title'],
        'package'        : issue['package'],
        'duplicate_title': dup_title,
    })
    return pred

_raw = run_concurrent(_dup_worker, issues_for_dup, desc=f'Dup | {DUP_MODEL}')
dup_results = []
for issue, r in zip(issues_for_dup, _raw):
    if isinstance(r, Exception):
        print(f"  Skipped #{issue['id']}: {r}")
    else:
        dup_results.append(r)

# Save CSV
keys = ['model','system','issue_id','title','package','is_duplicate','duplicate_of','duplicate_title','confidence','reason']
with open(path_dup_csv, 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=keys, extrasaction='ignore')
    writer.writeheader(); writer.writerows(dup_results)

n_flagged = sum(1 for r in dup_results if r['is_duplicate'])
print(f"\nFlagged as duplicate: {n_flagged}/{len(dup_results)}")
print(f"Saved → {path_dup_csv}")
dup_elapsed = time.time() - dup_start
print(f'[DUPLICATE] Runtime: {dup_elapsed:.1f}s ({dup_elapsed/60:.2f} min)')

# ── Evaluation (only on issues with known ground truth) ──────
# GT_TRUE_DUP comes straight from the state:duplicate label across the
# whole tracker (plus labeled_issues as confident negatives) — see CELL 4.
eval_results = [r for r in dup_results if r['issue_id'] in GT_TRUE_DUP]
n = len(eval_results)
if n:
    y_true = [GT_TRUE_DUP[r['issue_id']] for r in eval_results]
    y_pred = [bool(r['is_duplicate']) for r in eval_results]
    TP = sum(1 for t, p in zip(y_true, y_pred) if t and p)
    FP = sum(1 for t, p in zip(y_true, y_pred) if not t and p)
    TN = sum(1 for t, p in zip(y_true, y_pred) if not t and not p)
    FN = sum(1 for t, p in zip(y_true, y_pred) if t and not p)

    prec_pos = TP/(TP+FP) if (TP+FP)>0 else 0.0
    rec_pos  = TP/(TP+FN) if (TP+FN)>0 else 0.0
    f1_pos   = 2*prec_pos*rec_pos/(prec_pos+rec_pos) if (prec_pos+rec_pos)>0 else 0.0
    prec_neg = TN/(TN+FN) if (TN+FN)>0 else 0.0
    rec_neg  = TN/(TN+FP) if (TN+FP)>0 else 0.0
    f1_neg   = 2*prec_neg*rec_neg/(prec_neg+rec_neg) if (prec_neg+rec_neg)>0 else 0.0
    mac_f1   = (f1_pos + f1_neg) / 2
    acc      = (TP + TN) / n

    # Of the true positives, did we ALSO pick the correct partner issue?
    correct_pair = sum(
        1 for r in eval_results
        if GT_TRUE_DUP[r['issue_id']] and r['is_duplicate']
        and any(r['issue_id'] in pair and str(r.get('duplicate_of')) in pair for pair in GT_PAIRS_FULL)
    )

    print(f"\n{'='*65}")
    print(f"  DUPLICATE DETECTION RESULTS ({n} known-ground-truth issues: "
          f"{sum(GT_TRUE_DUP.values())} duplicate + "
          f"{sum(1 for v in GT_TRUE_DUP.values() if not v)} non-duplicate)")
    print(f"{'='*65}")
    print(f"  TP={TP}  FP={FP}  TN={TN}  FN={FN}")
    print(f"  P+={prec_pos:.4f}  R+={rec_pos:.4f}  F1+={f1_pos:.4f}")
    print(f"  P-={prec_neg:.4f}  R-={rec_neg:.4f}  F1-={f1_neg:.4f}")
    print(f"  Mac-F1={mac_f1:.4f}  Acc={acc:.4f}")
    print(f"  Correct duplicate partner identified: {correct_pair}/{TP if TP else 0}")
    print(f"{'='*65}")
else:
    print("\n  No known-ground-truth issues were in this run — skipping evaluation.")
    TP=FP=TN=FN=0; prec_pos=rec_pos=f1_pos=prec_neg=rec_neg=f1_neg=mac_f1=acc=0.0

# Filter duplicate issues from pipeline
duplicate_issue_ids    = {r['issue_id'] for r in dup_results if r['is_duplicate']}

# ── Save evaluation metrics to CSV ───────────────────────────
path_dup_metrics = f'{RESULTS_DIR}/metrics_dup_{DUP_SYSTEM}_{DUP_MODEL.replace(".","_")}.csv'
with open(path_dup_metrics, 'w', newline='') as _f:
    _w = csv.DictWriter(_f, fieldnames=['model','system','n_issues','TP','FP','TN','FN',
                                         'prec_pos','rec_pos','f1_pos',
                                         'prec_neg','rec_neg','f1_neg',
                                         'mac_p','mac_r','mac_f1',
                                         'wgt_p','wgt_r','wgt_f1','acc'])
    _w.writeheader()
    wgt_p_dup  = prec_neg
    wgt_r_dup  = rec_neg
    wgt_f1_dup = f1_neg
    _w.writerow(dict(model=DUP_MODEL, system=DUP_SYSTEM, n_issues=n,
                     TP=TP, FP=FP, TN=TN, FN=FN,
                     prec_pos=round(prec_pos,4), rec_pos=round(rec_pos,4), f1_pos=round(f1_pos,4),
                     prec_neg=round(prec_neg,4), rec_neg=round(rec_neg,4), f1_neg=round(f1_neg,4),
                     mac_p=round((prec_pos+prec_neg)/2,4), mac_r=round((rec_pos+rec_neg)/2,4),
                     mac_f1=round(mac_f1,4),
                     wgt_p=round(wgt_p_dup,4), wgt_r=round(wgt_r_dup,4), wgt_f1=round(wgt_f1_dup,4),
                     acc=round(acc,4)))
print(f"Metrics saved → {path_dup_metrics}")

print(f"\nNon-duplicate issues passing to next task: {len(issues_for_dup)}")
# Out:
# [DUPLICATE] Starting...
#
# Running duplicate detection — model: qwen2.5:14b, system: A
# Issues to process: 3546
# Known duplicate pairs: [{'11790', '11791'}, {'11948', '11462'}]
# Dup | qwen2.5:14b:   0%|          | 0/3546 [00:00<?, ?it/s]
#   [attempt 1] ValueError: Could not parse JSON from: {
#   "is_duplicate": false,
#   "duplicate_of": null,
#   "confidence"  : 0.0,
#   "reason"      : "None of the candidate issues report the same specific 'cd \\' failure as the query issue."
# }
#   [attempt 2] ValueError: Could not parse JSON from: {
#   "is_duplicate": false,
#   "duplicate_of": null,
#   "confidence"  : 0.0,
#   "reason"      : "None of the candidate issues report the same specific 'cd \\' command failure issue."
# }
#   [attempt 3] ValueError: Could not parse JSON from: {
#   "is_duplicate": false,
#   "duplicate_of": null,
#   "confidence"  : 0.0,
#   "reason"      : "None of the candidate issues report the same specific 'cd \\' failure as the query issue."
# }
#
# Flagged as duplicate: 265/3546
# Saved → /home/nsiavash/triage_framework/results/dup_A_qwen2_5:14b.csv
# [DUPLICATE] Runtime: 5716.8s (95.28 min)
#
# =================================================================
#   DUPLICATE DETECTION RESULTS (117 known-ground-truth issues: 80 duplicate + 37 non-duplicate)
# =================================================================
#   TP=22  FP=4  TN=33  FN=58
#   P+=0.8462  R+=0.2750  F1+=0.4151
#   P-=0.3626  R-=0.8919  F1-=0.5156
#   Mac-F1=0.4654  Acc=0.4701
#   Correct duplicate partner identified: 0/22
# =================================================================
# Metrics saved → /home/nsiavash/triage_framework/results/metrics_dup_A_qwen2_5:14b.csv
#
# Non-duplicate issues passing to next task: 3546

# %% [markdown]
# ## Task 3 — Priority Classification
#
# Best model: `claude-sonnet-4-6` System A

# %%
# ============================================================
# CELL 10 — Priority Classification
# Best model: claude-sonnet-4-6 System A
# ============================================================
from tqdm.notebook import tqdm
import csv, random
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, balanced_accuracy_score

pri_start = time.time()
print(f'[PRIORITY] Starting...')
random.seed(42)

PRI_MODEL  = LOCAL_MODEL           # ← local DeepSeek-R1-Distill-Qwen (active)
# PRI_MODEL = 'claude-sonnet-4-6'    # previous best model — Acc=0.627, Mac-F1=0.613
# PRI_MODEL = 'gpt-4o-mini'
# PRI_MODEL = 'gpt-4o'
# PRI_MODEL = 'gpt-4.1-mini'
# PRI_MODEL = 'gpt-4.1'
# PRI_MODEL = 'gpt-5.4-mini'
# PRI_MODEL = 'gpt-5.4'
# PRI_MODEL = 'gpt-5.5'
# PRI_MODEL = 'claude-haiku-4-5'
# PRI_MODEL = 'claude-opus-4-7'

PRI_SYSTEM = 'A'   # ← best system (active)
# PRI_SYSTEM = 'B'

RAG_TOP_K       = 5
PRIORITY_LABELS = ['low', 'medium', 'high']
PRIORITY_FEWSHOT_K = 30   # ← cap on few-shot examples per prompt — with priority: labels
                          #   now covering thousands of issues (not just ~36), dumping every
                          #   labeled example into every prompt would blow up context length

DOMAIN_RULES = """\
You are a bug priority classifier for the tianocore/edk2 UEFI firmware repository.

PRIORITY DEFINITIONS:
- high   : Crashes, data corruption, security vulnerabilities that directly
           apply to the UEFI threat model, or build failures that block ALL
           configurations for ALL users.
- medium : Functional bugs with workarounds, build failures limited to a
           specific compiler or toolchain, missing features required for spec
           compliance, race conditions that may cause instability.
- low    : Cosmetic issues, code quality improvements, warnings that do not
           block builds, missing optional features, documentation changes,
           bugs in non-default configurations.

DOMAIN KNOWLEDGE RULES for edk2 priority triage:

1. CVE / security updates are NOT automatically high. UEFI firmware has a
   different threat model than an OS. If the vulnerable code path in a library
   (e.g. OpenSSL) is not reachable during UEFI execution, the patch priority
   reflects maintenance urgency, not security severity.

2. Build failures severity depends on scope. A failure that blocks ALL users
   regardless of compiler or configuration is high. A failure limited to one
   specific compiler (e.g. VS2022 only, CLANG only) or one toolchain variant
   (e.g. CLANGPDB, CLANGDWARF) is medium. A warning that does not block the
   build at all is low.

3. UI and display bugs are low unless they completely prevent the user from
   interacting with the firmware (e.g. no input accepted at all).

4. Missing feature additions or spec compliance gaps are medium if the spec
   is published and widely adopted, low if the feature is optional or cosmetic.

5. ALWAYS use the training examples as your primary signal. If a similar bug
   in the examples was labeled low, do not escalate without a concrete reason
   specific to this bug that is not present in the example.
"""

JSON_INSTRUCTION = """\
Before predicting, scan the examples above for the most similar issue — same
package, same bug type. Use that example's label as your anchor. Only deviate
if there is a concrete, specific reason this issue is clearly more or less
severe than the similar example.

Only choose from: low, medium, high

Respond ONLY with a JSON object, nothing else — no prose before or after:
{"predicted_priority": "<low|medium|high>", "confidence": <float 0.0-1.0>, "reason": "<one sentence>"}"""

def fmt_issue_priority(issue, include_priority=True):
    body = str(issue.get('body','') or '')[:300].replace('\n',' ')
    pkg  = issue.get('package','') or 'unknown'
    text = f"Title   : {issue['title']}\nPackage : {pkg}\nBody    : {body}"
    if include_priority:
        text += f"\nPriority: {issue.get('priority','-')}"
    return text

def _sample_priority_train(test_issue, all_issues_df, k=PRIORITY_FEWSHOT_K):
    pool = [i for i in all_issues_df
            if i['id'] != test_issue['id'] and i.get('priority','').lower() in PRIORITY_LABELS]
    if len(pool) <= k:
        return pool
    # Stratified sample so all 3 priority levels stay represented even when capped
    by_label = {lab: [i for i in pool if i['priority'].lower() == lab] for lab in PRIORITY_LABELS}
    per_label = max(1, k // len(PRIORITY_LABELS))
    sample = []
    for lab in PRIORITY_LABELS:
        sample.extend(random.sample(by_label[lab], min(per_label, len(by_label[lab]))))
    return sample

def build_priority_prompt_A(test_issue, all_issues_df):
    train    = _sample_priority_train(test_issue, all_issues_df)
    examples = '\n\n'.join(fmt_issue_priority(i) for i in train)
    test     = fmt_issue_priority(test_issue, include_priority=False)
    return (DOMAIN_RULES + '\n---\nPast GitHub issues and their priority labels:\n\n'
            + examples + '\n\n---\nNew issue to classify:\n\n' + test
            + '\n\n' + JSON_INSTRUCTION), 'Classify the issue above.'

def build_priority_prompt_B(test_issue, all_issues_df):
    train    = _sample_priority_train(test_issue, all_issues_df)
    examples = '\n\n'.join(fmt_issue_priority(i) for i in train)
    rag_bugs = get_bz_priority_context(test_issue, k=RAG_TOP_K)
    rag_ctx  = '\n\n'.join(
        f"Title   : {b['title']}\nPackage : {b.get('package','')}\n"
        f"Body    : {str(b.get('body',''))[:200]}\nPriority: {b.get('priority','')}"
        for b in rag_bugs
    )
    test = fmt_issue_priority(test_issue, include_priority=False)
    return (DOMAIN_RULES + '\n---\nSIMILAR HISTORICAL BUGS from Bugzilla (RAG context):\n\n'
            + rag_ctx + '\n\n---\nPast GitHub issues:\n\n' + examples
            + '\n\n---\nNew issue to classify:\n\n' + test
            + '\n\n' + JSON_INSTRUCTION), 'Classify the issue above.'

def predict_priority(issue, all_issues_list, model=PRI_MODEL, system=PRI_SYSTEM):
    if system == 'A':
        sys_p, user_p = build_priority_prompt_A(issue, all_issues_list)
    else:
        sys_p, user_p = build_priority_prompt_B(issue, all_issues_list)
    result = call_llm(sys_p, user_p if user_p and user_p.strip() else 'Classify the issue above.', model, max_tokens=200)
    if result is None:
        return {'predicted_priority': None, 'confidence': 0.0, 'reason': 'error'}
    pred = result.get('predicted_priority','').strip().lower()
    if pred not in PRIORITY_LABELS:
        result['predicted_priority'] = None
    return result

# ── Run priority classification ───────────────────────────────
# `issues_with_priority` is already computed in CELL 4 from the live
# priority: labels across the WHOLE tracker (not just the curated 36) —
# used both as few-shot training examples and as the evaluation set.
# Predictions still run over every fetched issue; eval is scored only
# where we actually have a priority: label to compare against.
issues_for_pri = TARGET_ISSUES

print(f"\nRunning priority classification — model: {PRI_MODEL}, system: {PRI_SYSTEM}")
print(f"Issues to process: {len(issues_for_pri)}  (of which {len(issues_with_priority)} have known ground truth)")

path_pri_csv = f'{RESULTS_DIR}/priority_{PRI_SYSTEM}_{PRI_MODEL.replace(".","_")}.csv'

def _pri_worker(issue):
    pred = predict_priority(issue, issues_with_priority)
    pred.update({
        'model'         : PRI_MODEL,
        'system'        : PRI_SYSTEM,
        'issue_id'      : issue['id'],
        'title'         : issue['title'],
        'package'       : issue['package'],
        'true_priority' : issue.get('priority',''),
    })
    return pred

_raw = run_concurrent(_pri_worker, issues_for_pri, desc=f'Priority | {PRI_MODEL}')
pri_results = []
for issue, r in zip(issues_for_pri, _raw):
    if isinstance(r, Exception):
        print(f"  Skipped #{issue['id']}: {r}")
    else:
        pri_results.append(r)

# Save predictions CSV
keys = ['model','system','issue_id','title','package','predicted_priority','true_priority','confidence','reason']
with open(path_pri_csv, 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=keys, extrasaction='ignore')
    writer.writeheader()
    writer.writerows(pri_results)
print(f"Saved → {path_pri_csv}")

pri_elapsed = time.time() - pri_start
print(f'[PRIORITY] Runtime: {pri_elapsed:.1f}s ({pri_elapsed/60:.2f} min)')

# ── Evaluation ────────────────────────────────────────────────
labeled_pri = [r for r in pri_results
               if r.get('true_priority','').lower() in PRIORITY_LABELS
               and r.get('predicted_priority') is not None]
if labeled_pri:
    y_true  = [r['true_priority']      for r in labeled_pri]
    y_pred  = [r['predicted_priority'] for r in labeled_pri]
    acc     = accuracy_score(y_true, y_pred)
    bal_acc = balanced_accuracy_score(y_true, y_pred)
    mac_p   = precision_score(y_true, y_pred, average='macro',    zero_division=0)
    mac_r   = recall_score(   y_true, y_pred, average='macro',    zero_division=0)
    mac_f1  = f1_score(       y_true, y_pred, average='macro',    zero_division=0)
    wgt_p   = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    wgt_r   = recall_score(   y_true, y_pred, average='weighted', zero_division=0)
    wgt_f1  = f1_score(       y_true, y_pred, average='weighted', zero_division=0)
    correct = sum(1 for a, b in zip(y_true, y_pred) if a == b)
    print(f"\n{'='*55}")
    print(f"  PRIORITY RESULTS ({len(labeled_pri)} evaluated)")
    print(f"{'='*55}")
    print(f"  Correct    : {correct}/{len(labeled_pri)}")
    print(f"  Accuracy   : {acc:.4f}  |  Bal-Acc: {bal_acc:.4f}")
    print(f"  Mac  P/R/F1: {mac_p:.3f} / {mac_r:.3f} / {mac_f1:.3f}")
    print(f"  Wgt  P/R/F1: {wgt_p:.3f} / {wgt_r:.3f} / {wgt_f1:.3f}")
    print(f"{'='*55}")

    # Save evaluation metrics CSV
    path_pri_metrics = f'{RESULTS_DIR}/metrics_priority_{PRI_SYSTEM}_{PRI_MODEL.replace(".","_")}.csv'
    with open(path_pri_metrics, 'w', newline='') as _f:
        _w = csv.DictWriter(_f, fieldnames=['model','system','n_issues','acc','bal_acc',
                                             'mac_p','mac_r','mac_f1',
                                             'wgt_p','wgt_r','wgt_f1'])
        _w.writeheader()
        _w.writerow(dict(model=PRI_MODEL, system=PRI_SYSTEM, n_issues=len(labeled_pri),
                         acc=round(acc,4), bal_acc=round(bal_acc,4),
                         mac_p=round(mac_p,4), mac_r=round(mac_r,4), mac_f1=round(mac_f1,4),
                         wgt_p=round(wgt_p,4), wgt_r=round(wgt_r,4), wgt_f1=round(wgt_f1,4)))
    print(f"Metrics saved → {path_pri_metrics}")

print(f"\nAll {len(issues_for_pri)} issues continue to bug assignment (no exclusion).")
# Out:
# [PRIORITY] Starting...
#
# Running priority classification — model: qwen2.5:14b, system: A
# Issues to process: 3546  (of which 3545 have known ground truth)
# Priority | qwen2.5:14b:   0%|          | 0/3546 [00:00<?, ?it/s]
# Saved → /home/nsiavash/triage_framework/results/priority_A_qwen2_5:14b.csv
# [PRIORITY] Runtime: 32832.9s (547.22 min)
#
# =======================================================
#   PRIORITY RESULTS (3545 evaluated)
# =======================================================
#   Correct    : 1200/3545
#   Accuracy   : 0.3385  |  Bal-Acc: 0.3797
#   Mac  P/R/F1: 0.374 / 0.380 / 0.329
#   Wgt  P/R/F1: 0.459 / 0.339 / 0.339
# =======================================================
# Metrics saved → /home/nsiavash/triage_framework/results/metrics_priority_A_qwen2_5:14b.csv
#
# All 3546 issues continue to bug assignment (no exclusion).

# %% [markdown]
# ## Task 4 — Bug Assignment
#
# Best model: `gpt-5.5` System A
# Evaluated on 37 labeled issues

# %%
assign_start = time.time()
print(f'[BUG ASSIGN] Starting...')

# ============================================================
# CELL 11 — Bug Assignment
# Best model: gpt-5.5 System A
# ============================================================
from tqdm.notebook import tqdm
import csv, json
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

ASSIGN_MODEL  = LOCAL_MODEL         # ← local DeepSeek-R1-Distill-Qwen (active)
# ASSIGN_MODEL = 'gpt-5.5'            # previous best model — Acc=0.973, Mac-F1=0.977
# ASSIGN_MODEL = 'gpt-4o-mini'
# ASSIGN_MODEL = 'gpt-4o'
# ASSIGN_MODEL = 'gpt-4.1-mini'
# ASSIGN_MODEL = 'gpt-4.1'
# ASSIGN_MODEL = 'gpt-5.4-mini'
# ASSIGN_MODEL = 'gpt-5.4'
# ASSIGN_MODEL = 'claude-haiku-4-5'
# ASSIGN_MODEL = 'claude-sonnet-4-6'
# ASSIGN_MODEL = 'claude-opus-4-7'

ASSIGN_SYSTEM = 'A'   # ← best system (active)
# ASSIGN_SYSTEM = 'B'
RAG_K         = 5

PACKAGE_HINTS = """
IMPORTANT — Historical assignment patterns (use these as strong prior signals).
Read ALL sections carefully before predicting — many errors come from applying
a pattern too broadly without checking the specific sub-component or package.

─── MdeModulePkg / HII / HiiDatabase / SetupBrowser / UI forms ───────────────
  → YangGangUEFI has been assigned: HiiDatabaseDxe, GetNameElement, SetupBrowserDxe bugs
  → EricGao2015 has been assigned: Device Manager forms, Setup Hotkey display, Assert/string-id bugs
  → lgao4 has been assigned: core DXE infrastructure bugs (InstallProtocolInterface, protocol/handle
    management, general low-level MdeModulePkg issues NOT covered by YangGangUEFI or EricGao2015)
  → wenbhou has been assigned: variable store / FTW (Fault Tolerant Write) spare block recovery bugs
  WARNING: Do NOT assign variable store or FTW bugs to os-d — os-d handles physical memory,
  not variable storage. Do NOT assign InstallProtocolInterface bugs to YangGangUEFI — that is
  a core DXE function belonging to lgao4.

─── mikebeaton — IMPORTANT: CLANGPDB scope is LIMITED to RedfishPkg only ─────
  → mikebeaton has been assigned: CLANGPDB build/link errors ONLY in RedfishPkg
  → Do NOT assign a CLANGPDB bug to mikebeaton if the package is NOT RedfishPkg
  → If title says "CLANGPDB" but package is NOT RedfishPkg → check other assignees

─── CLANGPDB linker bugs OUTSIDE RedfishPkg ──────────────────────────────────
  → deeglaze has been assigned: CLANGPDB linker warnings in non-RedfishPkg contexts
    (e.g. "/align without /driver" warnings in general build toolchain)
  WARNING: "CLANGPDB" alone does NOT mean mikebeaton. Always check the package first.

─── NetworkPkg ───────────────────────────────────────────────────────────────
  → BritChesley has been assigned: CodeQL / static-analysis bugs in NetworkPkg
  → SaloniKasbekar has been assigned: hardcoded-value / define-constant bugs in NetworkPkg
  → AndreasBBS has been assigned: QEMU_EFI + NetworkPkg combined driver-loading bugs
    (bugs where BOTH OvmfPkg/QEMU_EFI AND NetworkPkg are involved together)
  WARNING: If the bug is NetworkPkg + QEMU_EFI combined → AndreasBBS, NOT SaloniKasbekar/BritChesley

─── OvmfPkg / memory management — os-d vs vit9696 are DIFFERENT sub-domains ──
  → os-d has been assigned: PHYSICAL memory bugs — FreePages(), page table inconsistency,
    GCD data structures, memory-protection feature bugs, MdePkg LNK2001 linker errors
  → vit9696 has been assigned: POLICY bugs — runtime driver executability after EndOfDxe,
    driver loading permissions, UEFI runtime driver access control
  CRITICAL: A bug about "drivers not executable" or "EndOfDxe" → vit9696, NOT os-d
  CRITICAL: MdePkg LNK2001 unresolved symbol errors (e.g. __security_pop_cookie) → os-d,
    NOT ardbiesheuvel (ardbiesheuvel handles CryptoPkg VS2022 build errors, not MdePkg linker)

─── OvmfPkg / RISC-V ────────────────────────────────────────────────────────
  → yechao-w has been assigned: QEMU-KVM guest-boot failure bugs on RISC-V
  → zevorn has been assigned: OS-runtime crash bugs in RISC-V timer libs (BaseRiscV64CpuTimerLib)
  → jxu023 has been assigned: AMD SEV / SEV-ES virtualisation boot bugs in OvmfPkg
    (bugs mentioning AmdSvsm, SEV, SEV-ES → jxu023, NOT yechao-w)
  WARNING: yechao-w is RISC-V QEMU boot only. SEV/AMD bugs → jxu023.

─── OvmfPkg / Arm platform firmware menus ────────────────────────────────────
  → mikebeaton has been assigned: bugs where a specific commit broke key response
    in Arm platform firmware menus (regression bugs referencing a commit hash, NOT general UI)
  WARNING: Do NOT assign Arm firmware menu key-response regression bugs to YangGangUEFI or
  EricGao2015 — these are firmware-level regressions handled by mikebeaton, not HII/UI bugs.

─── ShellPkg / SMBIOS / SmbioView ───────────────────────────────────────────
  → praveensankarn has been assigned: ARMV9 / processor support additions in SmbioView
  → NingFengGit has been assigned: MRDIMM / MemoryDevice table additions in ShellPkg SMBIOS

─── CryptoPkg / build errors ─────────────────────────────────────────────────
  → mdkinney has been assigned: CLANG compiler build error bugs in CryptoPkg
  → ardbiesheuvel has been assigned: VS2022 build error bugs in CryptoPkg
  → liyi77 has been assigned: OpenSSL version update / CVE patch bugs in CryptoPkg
  WARNING: ardbiesheuvel is CryptoPkg + VS2022 ONLY. MdePkg linker errors → os-d, not ardbiesheuvel.

─── BaseTools / CI ───────────────────────────────────────────────────────────
  → bexcran has been assigned: ECC Check / CI failure bugs in BaseTools
  → makubacki has been assigned: NASM / toolchain / nuget update bugs in BaseTools

─── Assignees with unique bug types ─────────────────────────────────────────
  → HunterChang030: SecurityPkg / OpalPassword device list handling bugs
  → philnoh2: UefiCpuPkg BSP/AP multiprocessor synchronisation bugs
  → praravin: IntelFsp2Pkg / FSP-T TemporaryRamSize configuration bugs
  When a bug clearly matches one of these descriptions, use that assignee even at low
  confidence — do NOT default to a more frequently seen assignee.
"""
_ASSIGN_TEMPLATE = """You are a bug triage assistant for the tianocore/edk2 UEFI firmware repository.

{package_hints}
---
Below are past bug issues and their assignees:

{examples}

---
New bug to assign:

{test_issue}

Before predicting, reason through these steps:
  1. What is the exact package (e.g. RedfishPkg, MdePkg, SecurityPkg)?
  2. What is the specific sub-component or bug type within that package?
  3. Which historical pattern matches most precisely?
  4. Is there a rare assignee listed in the hints who matches better than a common one?

Only choose from this list: {known}

Respond ONLY with a JSON object, nothing else:
{{"predicted_assignee": "<login>", "confidence": <float 0.0-1.0>, "reason": "<one sentence>"}}"""

def fmt_issue_example(issue, include_assignee=True):
    useful_labels = []
    if issue.get('package') and issue['package'] != '-':
        useful_labels.append(f"package:{issue['package']}")
    if issue.get('priority') and issue['priority'] != '-':
        useful_labels.append(f"priority:{issue['priority']}")
    label_str    = ', '.join(useful_labels) if useful_labels else 'none'
    body_preview = str(issue['title'])[:300].replace('\n', ' ').strip()
    text = (f"Title  : {issue['title']}\n"
            f"Labels : {label_str}\n"
            f"Body   : {body_preview}")
    if include_assignee and issue.get('true_assignee'):
        text += f"\nAssignee: {issue['true_assignee']}"
    return text

def fmt_issue_query(issue):
    return fmt_issue_example(issue, include_assignee=False)

def parse_assignment(raw_result):
    if raw_result is None: return None
    # .get(key, default) only falls back when the KEY is missing — if the
    # model returns valid JSON with "predicted_assignee": null, .get() returns
    # None here, and None.strip() throws. `or ''` catches both cases.
    assignee = (raw_result.get('predicted_assignee') or '').strip()
    if assignee not in KNOWN_ASSIGNEES:
        match    = next((a for a in KNOWN_ASSIGNEES if a.lower()==assignee.lower()), None)
        # KNOWN_ASSIGNEES can be empty if no ground-truth CSV was found —
        # don't crash with IndexError, just leave it unresolved.
        assignee = match if match else (KNOWN_ASSIGNEES[0] if KNOWN_ASSIGNEES else None)
        raw_result['predicted_assignee'] = assignee
        raw_result['corrected']          = True
    return raw_result

def predict_assign_A(issue, model=ASSIGN_MODEL):
    """System A: Leave-one-out — all 37 labeled issues except current one."""
    examples = [i for i in labeled_issues if i['id'] != issue['id']]
    prompt   = _ASSIGN_TEMPLATE.format(
        package_hints = PACKAGE_HINTS,
        examples      = '\n\n'.join(fmt_issue_example(i) for i in examples),
        test_issue    = fmt_issue_query(issue),
        known         = ', '.join(sorted(KNOWN_ASSIGNEES)),
    )
    return parse_assignment(call_llm(prompt, ' ', model, max_tokens=500))

def predict_assign_B(issue, model=ASSIGN_MODEL):
    """System B: RAG — top-k similar labeled issues."""
    similar  = get_similar_labeled(issue, k=RAG_K)
    prompt   = _ASSIGN_TEMPLATE.format(
        package_hints = PACKAGE_HINTS,
        examples      = '\n\n'.join(fmt_issue_example(i) for i in similar),
        test_issue    = fmt_issue_query(issue),
        known         = ', '.join(sorted(KNOWN_ASSIGNEES)),
    )
    return parse_assignment(call_llm(prompt, ' ', model, max_tokens=500))

predict_assign_fn = predict_assign_A if ASSIGN_SYSTEM == 'A' else predict_assign_B

# ── Run bug assignment ────────────────────────────────────────
# Training examples (in predict_assign_A/B) always come from the 37 known-
# labeled issues. Predictions now run over every fetched issue — production
# routing for the rest, with real evaluation kept only where true_assignee
# is known (i.e. the labeled_issues subset).
print(f"\nRunning bug assignment — model: {ASSIGN_MODEL}, system: {ASSIGN_SYSTEM}")
print(f"Issues to process: {len(TARGET_ISSUES)}  (of which {len(labeled_issues)} have known ground truth)")

if not KNOWN_ASSIGNEES:
    raise RuntimeError(
        'KNOWN_ASSIGNEES is empty — this almost always means full-edkII-dd.csv\n'
        'was not found on the server (check GITHUB_CSV in CELL 3/4). Bug\n'
        'Assignment has no one to route bugs to without it, so there is no\n'
        'point running 3,546 calls that can never produce a real answer.\n'
        'Copy the CSV to the DATA_DIR printed in CELL 2, then re-run CELL 4\n'
        'before this cell.'
    )

path_assign_csv = f'{RESULTS_DIR}/assignee_{ASSIGN_SYSTEM}_{ASSIGN_MODEL.replace(".","_")}.csv'

def _assign_worker(issue):
    pred = predict_assign_fn(issue)
    if pred is None:
        pred = {'predicted_assignee': None, 'confidence': 'low', 'reason': 'error'}
    return {
        'model'              : ASSIGN_MODEL,
        'system'             : ASSIGN_SYSTEM,
        'issue_id'           : issue['id'],
        'title'              : issue['title'],
        'package'            : issue['package'],
        'type'               : issue.get('type','-'),
        'priority'           : issue.get('priority','-'),
        'predicted_assignee' : pred.get('predicted_assignee'),
        'confidence'         : pred.get('confidence','low'),
        'reason'             : pred.get('reason',''),
        'true_assignee'      : issue['true_assignee'],
        'correct'            : pred.get('predicted_assignee') == issue['true_assignee'],
    }

_raw = run_concurrent(_assign_worker, TARGET_ISSUES, desc=f'Assign | {ASSIGN_MODEL}')
assign_results = []
for issue, r in zip(TARGET_ISSUES, _raw):
    if isinstance(r, Exception):
        print(f"  Skipped #{issue['id']}: {r}")
    else:
        assign_results.append(r)

# Save CSV
keys = ['model','system','issue_id','title','package','type','priority',
        'predicted_assignee','confidence','reason','true_assignee','correct']
with open(path_assign_csv, 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=keys, extrasaction='ignore')
    writer.writeheader(); writer.writerows(assign_results)

# ── Evaluation ────────────────────────────────────────────────
labeled_r = [r for r in assign_results if r['true_assignee'] is not None and r['predicted_assignee'] is not None]
if labeled_r:
    y_true  = [r['true_assignee']      for r in labeled_r]
    y_pred  = [r['predicted_assignee'] for r in labeled_r]
    correct = sum(1 for r in labeled_r if r['correct'])
    acc     = accuracy_score(y_true, y_pred)
    mac_p   = precision_score(y_true, y_pred, average='macro',    zero_division=0)
    mac_r   = recall_score(   y_true, y_pred, average='macro',    zero_division=0)
    mac_f1  = f1_score(       y_true, y_pred, average='macro',    zero_division=0)
    wgt_p   = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    wgt_r   = recall_score(   y_true, y_pred, average='weighted', zero_division=0)
    wgt_f1  = f1_score(       y_true, y_pred, average='weighted', zero_division=0)
    print(f"\n{'='*55}")
    print(f"  BUG ASSIGNMENT RESULTS ({len(labeled_r)} evaluated)")
    print(f"{'='*55}")
    print(f"  Correct  : {correct}/{len(labeled_r)}")
    print(f"  Accuracy : {acc:.4f}")
    print(f"  Mac  P/R/F1: {mac_p:.3f} / {mac_r:.3f} / {mac_f1:.3f}")
    print(f"  Wgt  P/R/F1: {wgt_p:.3f} / {wgt_r:.3f} / {wgt_f1:.3f}")
    print(f"{'='*55}")
    print(f"Saved → {path_assign_csv}")

# ── Save evaluation metrics to CSV ───────────────────────────
if labeled_r:
    path_assign_metrics = f'{RESULTS_DIR}/metrics_assignee_{ASSIGN_SYSTEM}_{ASSIGN_MODEL.replace(".","_")}.csv'
    with open(path_assign_metrics, 'w', newline='') as _f:
        _w = csv.DictWriter(_f, fieldnames=['model','system','n_issues','correct','acc',
                                             'mac_p','mac_r','mac_f1',
                                             'wgt_p','wgt_r','wgt_f1'])
        _w.writeheader()
        _w.writerow(dict(model=ASSIGN_MODEL, system=ASSIGN_SYSTEM, n_issues=len(labeled_r),
                         correct=correct, acc=round(acc,4),
                         mac_p=round(mac_p,4), mac_r=round(mac_r,4), mac_f1=round(mac_f1,4),
                         wgt_p=round(wgt_p,4), wgt_r=round(wgt_r,4), wgt_f1=round(wgt_f1,4)))
    print(f"Metrics saved → {path_assign_metrics}")
assign_elapsed = time.time() - assign_start
print(f'[BUG ASSIGN] Runtime: {assign_elapsed:.1f}s ({assign_elapsed/60:.2f} min)')
# Out:
# [BUG ASSIGN] Starting...
#
# Running bug assignment — model: qwen2.5:14b, system: A
# Issues to process: 3546  (of which 37 have known ground truth)
# Assign | qwen2.5:14b:   0%|          | 0/3546 [00:00<?, ?it/s]
# =======================================================
#   BUG ASSIGNMENT RESULTS (37 evaluated)
# =======================================================
#   Correct  : 24/37
#   Accuracy : 0.6486
#   Mac  P/R/F1: 0.659 / 0.695 / 0.666
#   Wgt  P/R/F1: 0.627 / 0.649 / 0.623
# =======================================================
# Saved → /home/nsiavash/triage_framework/results/assignee_A_qwen2_5:14b.csv
# Metrics saved → /home/nsiavash/triage_framework/results/metrics_assignee_A_qwen2_5:14b.csv
# [BUG ASSIGN] Runtime: 22265.1s (371.08 min)

# %%
# ============================================================
# CELL 12b — Merge all predictions into one unified CSV
# ============================================================
import pandas as pd
import os

print("Individual CSVs saved per task:")
print(f"  Invalid    : {path_inv_csv}")
print(f"  Duplicate  : {path_dup_csv}")
print(f"  Priority   : {path_pri_csv}")
print(f"  Assignment : {path_assign_csv}")

# ── Build unified per-issue summary ──────────────────────────
# One row per issue with predictions from all 4 tasks — covers every issue
# that went through the pipeline (TARGET_ISSUES), not just the known-GT set.
issue_map = {i['id']: {'issue_id': i['id'], 'title': i['title'],
                        'package': i['package'],
                        'true_priority': GT_PRIORITY.get(i['id'], ''),
                        'true_assignee': GT_ASSIGNEE.get(i['id'], '')} for i in TARGET_ISSUES}

# Add invalid predictions
for r in invalid_results:
    iid = r['issue_id']
    if iid in issue_map:
        issue_map[iid]['pred_invalid']    = r.get('is_invalid', False)
        issue_map[iid]['invalid_conf']    = r.get('confidence', '')
        issue_map[iid]['invalid_reason']  = r.get('reason', '')

# Add duplicate predictions
for r in dup_results:
    iid = r['issue_id']
    if iid in issue_map:
        issue_map[iid]['pred_duplicate']       = r.get('is_duplicate', False)
        issue_map[iid]['duplicate_of']         = r.get('duplicate_of', '')
        issue_map[iid]['duplicate_title']      = r.get('duplicate_title', '')
        issue_map[iid]['duplicate_conf']       = r.get('confidence', '')

# Add priority predictions
for r in pri_results:
    iid = r['issue_id']
    if iid in issue_map:
        issue_map[iid]['pred_priority']   = r.get('predicted_priority', '')
        issue_map[iid]['priority_conf']   = r.get('confidence', '')
        issue_map[iid]['priority_reason'] = r.get('reason', '')
        issue_map[iid]['priority_correct'] = (
            str(r.get('predicted_priority','')).lower() ==
            str(r.get('true_priority','')).lower()
        )

# Add assignment predictions
for r in assign_results:
    iid = r['issue_id']
    if iid in issue_map:
        issue_map[iid]['pred_assignee']    = r.get('predicted_assignee', '')
        issue_map[iid]['assignee_conf']    = r.get('confidence', '')
        issue_map[iid]['assignee_reason']  = r.get('reason', '')
        issue_map[iid]['assign_correct']   = r.get('correct', False)

# Build DataFrame
unified_cols = [
    'issue_id', 'title', 'package',
    # Invalid
    'pred_invalid', 'invalid_conf', 'invalid_reason',
    # Duplicate
    'pred_duplicate', 'duplicate_of', 'duplicate_title', 'duplicate_conf',
    # Priority
    'true_priority', 'pred_priority', 'priority_conf', 'priority_reason', 'priority_correct',
    # Assignment
    'true_assignee', 'pred_assignee', 'assignee_conf', 'assignee_reason', 'assign_correct',
]

rows = []
for iid in sorted(issue_map.keys(), key=int):
    row = issue_map[iid]
    rows.append({col: row.get(col, '') for col in unified_cols})

df_unified = pd.DataFrame(rows, columns=unified_cols)

# Cast boolean columns to proper bool type
for _bool_col in ['pred_invalid', 'pred_duplicate', 'priority_correct', 'assign_correct']:
    if _bool_col in df_unified.columns:
        df_unified[_bool_col] = df_unified[_bool_col].map(
            lambda x: True if str(x).strip().lower() in ('true','1','yes') else False
        )

path_unified = f'{RESULTS_DIR}/unified_predictions.csv'
df_unified.to_csv(path_unified, index=False)
print(f"\n✅ Unified predictions CSV saved → {path_unified}")
print(f"   Rows: {len(df_unified)}  |  Columns: {len(df_unified.columns)}")
print(f"\nColumn overview:")
for c in unified_cols:
    print(f"  {c}")

# Quick summary
print(f"\n{'='*55}")
print(f"  PIPELINE SUMMARY — {len(df_unified)} issues")
print(f"{'='*55}")
if 'pred_invalid' in df_unified.columns:
    print(f"  Flagged invalid   : {df_unified['pred_invalid'].sum()}")
if 'pred_duplicate' in df_unified.columns:
    print(f"  Flagged duplicate : {df_unified['pred_duplicate'].sum()}")
if 'priority_correct' in df_unified.columns:
    pc = df_unified['priority_correct'].sum()
    print(f"  Priority correct  : {pc}/{len(df_unified)}  ({pc/len(df_unified)*100:.1f}%)")
if 'assign_correct' in df_unified.columns:
    ac = df_unified['assign_correct'].sum()
    print(f"  Assignment correct: {ac}/{len(df_unified)}  ({ac/len(df_unified)*100:.1f}%)")
print(f"{'='*55}")
# Out:
# Individual CSVs saved per task:
#   Invalid    : /home/nsiavash/triage_framework/results/invalid_A_qwen2_5:14b.csv
#   Duplicate  : /home/nsiavash/triage_framework/results/dup_A_qwen2_5:14b.csv
#   Priority   : /home/nsiavash/triage_framework/results/priority_A_qwen2_5:14b.csv
#   Assignment : /home/nsiavash/triage_framework/results/assignee_A_qwen2_5:14b.csv
#
# ✅ Unified predictions CSV saved → /home/nsiavash/triage_framework/results/unified_predictions.csv
#    Rows: 3546  |  Columns: 20
#
# Column overview:
#   issue_id
#   title
#   package
#   pred_invalid
#   invalid_conf
#   invalid_reason
#   pred_duplicate
#   duplicate_of
#   duplicate_title
#   duplicate_conf
#   true_priority
#   pred_priority
#   priority_conf
#   priority_reason
#   priority_correct
#   true_assignee
#   pred_assignee
#   assignee_conf
#   assignee_reason
#   assign_correct
#
# =======================================================
#   PIPELINE SUMMARY — 3546 issues
# =======================================================
#   Flagged invalid   : 78
#   Flagged duplicate : 265
#   Priority correct  : 1200/3546  (33.8%)
#   Assignment correct: 24/3546  (0.7%)
# =======================================================

# %% [markdown]
# ## Summary — Integrated Pipeline Results

# %%
# ============================================================
# CELL 12 — Integrated Pipeline Summary
# ============================================================
import pandas as pd

print("=" * 65)
print("  INTEGRATED TRIAGE FRAMEWORK — PIPELINE SUMMARY")
print("=" * 65)

# Invalid
if 'invalid_results' in dir() and invalid_results:
    n_inv = sum(1 for r in invalid_results if r['is_invalid'])
    print(f"\n[1] INVALID DETECTION  (model: {INVALID_MODEL}, sys: {INVALID_SYSTEM})")
    print(f"    Issues processed : {len(invalid_results)}")
    print(f"    Flagged invalid  : {n_inv}")
    print(f"    Passed forward   : {len(invalid_results) - n_inv}")

# Duplicate
if 'dup_results' in dir() and dup_results:
    n_dup = sum(1 for r in dup_results if r['is_duplicate'])
    print(f"\n[2] DUPLICATE DETECTION (model: {DUP_MODEL}, sys: {DUP_SYSTEM})")
    print(f"    Issues processed : {len(dup_results)}")
    print(f"    Flagged duplicate: {n_dup}")
    print(f"    Passed forward   : {len(dup_results) - n_dup}")
    if n_dup > 0:
        flagged = [(r['issue_id'], r['title'][:50], r['duplicate_of'])
                   for r in dup_results if r['is_duplicate']]
        for iid, title, dup_of in flagged:
            print(f"    ↳ #{iid} '{title}' → dup of #{dup_of}")

# Priority
if 'pri_results' in dir() and pri_results:
    from collections import Counter
    dist = Counter(r.get('predicted_priority','?') for r in pri_results)
    print(f"\n[3] PRIORITY CLASSIFICATION (model: {PRI_MODEL}, sys: {PRI_SYSTEM})")
    print(f"    Issues processed : {len(pri_results)}")
    for label in ['high','medium','low']:
        print(f"    {label:8s}: {dist.get(label,0)}")

# Bug assignment
if 'assign_results' in dir() and assign_results:
    from collections import Counter
    assignee_dist = Counter(r['predicted_assignee'] for r in assign_results if r.get('predicted_assignee'))
    print(f"\n[4] BUG ASSIGNMENT  (model: {ASSIGN_MODEL}, sys: {ASSIGN_SYSTEM})")
    print(f"    Issues evaluated : {len(assign_results)}")
    correct_count = sum(1 for r in assign_results if r.get('correct'))
    print(f"    Correct          : {correct_count}/{len(assign_results)}")
    print(f"    Assignee distribution:")
    for assignee, count in sorted(assignee_dist.items(), key=lambda x:-x[1]):
        print(f"      {assignee:20s}: {count}")

print("\n" + "=" * 65)
print(f"  All results saved to: {RESULTS_DIR}")
print("=" * 65)


# ── Runtime summary ───────────────────────────────────────────
print(f"\n{'='*65}")
print(f"  RUNTIME SUMMARY")
print(f"{'='*65}")
task_times = {
    'Invalid Detection'      : locals().get('invalid_elapsed', None),
    'Duplicate Detection'    : locals().get('dup_elapsed',     None),
    'Priority Classification': locals().get('pri_elapsed',     None),
    'Bug Assignment'         : locals().get('assign_elapsed',  None),
}
for task, t in task_times.items():
    if t is not None:
        print(f"  {task:<25}: {t:.1f}s  ({t/60:.2f} min)")
    else:
        print(f"  {task:<25}: not run")

if 'setup_elapsed' in dir():
    print(f"  {'─'*40}")
    print(f"  {'Setup (CSV+index)':<25}: {setup_elapsed:.1f}s  ({setup_elapsed/60:.2f} min)")

inference_elapsed = time.time() - inference_start_time if 'inference_start_time' in dir() else None
if inference_elapsed is not None:
    print(f"  {'Inference (LLM only)':<25}: {inference_elapsed:.1f}s  ({inference_elapsed/60:.2f} min)")

if 'pipeline_start_time' in dir():
    total_elapsed = time.time() - pipeline_start_time
    print(f"  {'─'*40}")
    print(f"  {'TOTAL (setup+inference)':<25}: {total_elapsed:.1f}s  ({total_elapsed/60:.2f} min)")
print(f"{'='*65}")


# ── Save runtime to CSV ───────────────────────────────────────
import csv as _csv
path_runtime_csv = f'{RESULTS_DIR}/runtime_summary.csv'
with open(path_runtime_csv, 'w', newline='') as _f:
    _w = _csv.DictWriter(_f, fieldnames=['task','model','system',
                                          'runtime_seconds','runtime_minutes'])
    _w.writeheader()
    task_info = [
        ('Invalid Detection',       INVALID_MODEL, INVALID_SYSTEM, locals().get('invalid_elapsed')),
        ('Duplicate Detection',     DUP_MODEL,     DUP_SYSTEM,     locals().get('dup_elapsed')),
        ('Priority Classification', PRI_MODEL,     PRI_SYSTEM,     locals().get('pri_elapsed')),
        ('Bug Assignment',          ASSIGN_MODEL,  ASSIGN_SYSTEM,  locals().get('assign_elapsed')),
    ]
    for task, model, system, t in task_info:
        if t is not None:
            _w.writerow(dict(task=task, model=model, system=system,
                             runtime_seconds=round(t,2),
                             runtime_minutes=round(t/60,4)))
    # Total
    if 'setup_elapsed' in dir():
        _w.writerow(dict(task='SETUP (CSV+index)', model='all', system='all',
                         runtime_seconds=round(setup_elapsed,2),
                         runtime_minutes=round(setup_elapsed/60,4)))
    if inference_elapsed is not None:
        _w.writerow(dict(task='INFERENCE (LLM only)', model='all', system='all',
                         runtime_seconds=round(inference_elapsed,2),
                         runtime_minutes=round(inference_elapsed/60,4)))
    if 'pipeline_start_time' in dir():
        total = time.time() - pipeline_start_time
        _w.writerow(dict(task='TOTAL (setup+inference)', model='all', system='all',
                         runtime_seconds=round(total,2),
                         runtime_minutes=round(total/60,4)))
print(f"Runtime saved → {path_runtime_csv}")
# Out:
# =================================================================
#   INTEGRATED TRIAGE FRAMEWORK — PIPELINE SUMMARY
# =================================================================
#
# [1] INVALID DETECTION  (model: qwen2.5:14b, sys: A)
#     Issues processed : 3546
#     Flagged invalid  : 78
#     Passed forward   : 3468
#
# [2] DUPLICATE DETECTION (model: qwen2.5:14b, sys: A)
#     Issues processed : 3546
#     Flagged duplicate: 265
#     Passed forward   : 3281
#     ↳ #12397 '[Bug]: NvmeDxe:: NvmExpressMediaClear: Incorrect b' → dup of #12396
#     ↳ #12293 '[Bug]: GenFw Missing option on VS2026' → dup of #6899
#     ↳ #12176 '[Bug]: Cannot run posix wrappers without setup' → dup of #8342
#     ↳ #11948 '[Bug]: Mismatch in the value of LAST_ATTEMPT_STATU' → dup of #11462
#     ↳ #11786 '[Bug]: SetupBrowserDxe build fails with CLANGPDB' → dup of #13065
#     ↳ #11764 '[Bug]: SmiHandlerUnRegister  is pended forever whe' → dup of #6923
#     ↳ #11554 '[Bug]: <title> Pci command -i can't display PCIe D' → dup of #10430
#     ↳ #11462 '[Bug]: LAST_ATTEMPT_STATUS_ERROR_UNSUCCESSFUL_VEND' → dup of #11948
#     ↳ #11394 '[Bug]: BSP could free AP reset vector buffer even ' → dup of #10035
#     ↳ #11360 '[Bug]: TCG2/TPM2 support on RISC-V does not work' → dup of #11509
#     ↳ #11224 '[Bug]: An assertion occurred: ASSERT [DxeCore] edk' → dup of #11269
#     ↳ #11193 '[Bug]: HashLibTpm2 hash algorithm selection logic ' → dup of #6751
#     ↳ #11118 '[Bug]: Var Store Fails to Recover from FTW Spare B' → dup of #9329
#     ↳ #11074 '[Bug]: default OVMF build overwrites memory on Fre' → dup of #11046
#     ↳ #10896 '[Bug]: UefiPayloadPkg: Image Section Alignment doe' → dup of #9135
#     ↳ #10741 '[Bug]: Out-of-Bounds Memory Access in Percent-Deco' → dup of #7527
#     ↳ #10740 '[Bug]: CLANGDWARF Fails to Trigger Recompilation W' → dup of #10739
#     ↳ #10739 '[Bug]: CLANGDWARF Fails to Trigger Recompilation W' → dup of #10740
#     ↳ #10553 'After openssl is upgraded facing __GNUC__  safe_ma' → dup of #9321
#     ↳ #9548 '[MdeModulePkg|UEFIPayLoadPkg] Func SetPageTablePoo' → dup of #10305
#     ↳ #9529 'Some string and code logical are incorrect for SMB' → dup of #9181
#     ↳ #10530 'BDS boot time significantly increased due to CoreV' → dup of #9620
#     ↳ #10527 'The OVMF packages can not work properly when it wa' → dup of #10471
#     ↳ #9513 'GitHub CI PatchCheck.py false positive (Bugzilla B' → dup of #8104
#     ↳ #9512 'Shell command 'pci' for gen6 device show incorrect' → dup of #8048
#     ↳ #10513 'Tool build fail with "VS2015" (let "TOOL_CHAIN_TAG' → dup of #7542
#     ↳ #10510 'Null Pointer dereference in Private Data Macros (B' → dup of #10502
#     ↳ #9502 '[TDVF] Move TdTcg2Dxe and HashLibTdx from Security' → dup of #9273
#     ↳ #10502 'NULL pointer de-reference (Bugzilla Bug 4748)' → dup of #10510
#     ↳ #10494 'MdeModulePkg: Increase 1ms extra delay for xHCI re' → dup of #6638
#     ↳ #9481 'PatchCheck silently ignores commit message signatu' → dup of #9480
#     ↳ #9480 'PatchCheck silently ignores commit message signatu' → dup of #9481
#     ↳ #9471 'edk2 - Basetools SyntaxWarning: invalid escape seq' → dup of #9467
#     ↳ #10473 'FirmwarePerformaceCommonEntryPoint code improvemen' → dup of #10500
#     ↳ #9419 'ek2-libc: socket module of python UEFI interpreter' → dup of #10266
#     ↳ #9412 'MadtMpWk->MailBoxVersion = 1;  should be 0 accordi' → dup of #10415
#     ↳ #10415 'Incorrect MADT Revision for ACPI 6.5 (Bugzilla Bug' → dup of #6615
#     ↳ #9353 '[MTL] HDDPassword driver must transition from Vari' → dup of #10180
#     ↳ #9339 'Correct-MAX_LOGICAL_PROCESSORS-value (Bugzilla Bug' → dup of #9338
#     ↳ #9285 'NetworkPkg/HttpDxe: Coverity scan flags NULL_RETUR' → dup of #10319
#     ↳ #10312 'The strings of the Smbiostype0 BIOS Characteristic' → dup of #9523
#     ↳ #10310 'Replace Variable Lock Protocol with Variable Polic' → dup of #8884
#     ↳ #10305 'DxeIpl: Code logic in SetPageTablePoolReadOnly() d' → dup of #9548
#     ↳ #9251 'Faulty Rng algo selection for Arm (Bugzilla Bug 41' → dup of #9250
#     ↳ #10297 'Multiple Coverity issues were found from EDK2 Shel' → dup of #9248
#     ↳ #10274 'Fix bug on SR-IOV device multi functions(over 8) r' → dup of #10273
#     ↳ #10273 'Correct SR-IOV reserved bus numbers calculation me' → dup of #10274
#     ↳ #10266 'Uefi Python368 port - unable to import socket libr' → dup of #9419
#     ↳ #9168 'EDKII HII Browser does not apply configuration val' → dup of #10484
#     ↳ #10253 'Sha1 functions not surrounded by SHA1 deprecated d' → dup of #Issue #10429
#     ↳ #10243 'UefiPayloadPkg: Add macro to support selective dri' → dup of #9169
#     ↳ #9146 'UefiPayloadPkg: Align Attribute value with UPL spe' → dup of #9253
#     ↳ #9140 'Follow UEFI spec'd way to reconnect in form browse' → dup of #8477
#     ↳ #9139 'VM stuck at initializing guest display with Secure' → dup of #10527
#     ↳ #10235 'ECC fails to run (Bugzilla Bug 3945)' → dup of #7778
#     ↳ #10224 'SecurityPKg : sync the PcdTpm2HashMask to the acti' → dup of #8903
#     ↳ #9125 'Add XHCI handle Port Speed field value of PORTSC a' → dup of #7582
#     ↳ #9102 'CryptoPkg: should list all used library in dsc fil' → dup of #8202
#     ↳ #10208 'ECC check failed under Linux (Bugzilla Bug 3868)' → dup of #8569
#     ↳ #9089 'Revise UEfiCpuPkg to accomodate all processor arch' → dup of #6908
#     ↳ #9083 'MdePackage/PeiDxeDebugLibReportStatusCode：Add Stan' → dup of #8977
#     ↳ #10199 'UnitTestFrameworkPkg - Unit Test Log output is tru' → dup of #9951
#     ↳ #10186 'issue in SR-IOV reserve bus caculation (Bugzilla B' → dup of #10273
#     ↳ #10180 'EDK2 TCG & HDD Drivers must transition from Variab' → dup of #9353
#     ↳ #9025 'Fix OvmfPkg Microvm builds with VS2019 NOOPT (edk2' → dup of #9022
#     ↳ #10164 'Action is set to 'untested' if image is unsigned a' → dup of #9021
#     ↳ #9021 'Action is set to 'untested' if image signature is ' → dup of #10164
#     ↳ #8995 'Configure/Enable elliptic curve ciphers in OpenSSL' → dup of #8526
#     ↳ #10150 'Errors during compilation will be garbled (Bugzill' → dup of #8986
#     ↳ #8986 'Errors during compilation will be garbled (Bugzill' → dup of #10150
#     ↳ #10149 'Set default Makefile name when building module/lib' → dup of #8193
#     ↳ #10143 'The CCFlag generated in PcdValueInit makefile is i' → dup of #7657
#     ↳ #10142 'BaseTools: Dsc Parser scanning same file/line in c' → dup of #8290
#     ↳ #10140 'CPU Stack Guard cannot be enabled (Bugzilla Bug 36' → dup of #7559
#     ↳ #8974 'Mm Communication Ppi is not defined in MdePkg (Bug' → dup of #8878
#     ↳ #8970 'Refactor initialization of CPU features during S3 ' → dup of #8975
#     ↳ #10136 'Build races+failure with -j > 1 in MAKEFLAGS (Bugz' → dup of #7184
#     ↳ #8944 'CoreValidateHandle has the risk of invalid memory ' → dup of #10031
#     ↳ #8936 'Learn how to use the Cash app refund to challenge ' → dup of #8927
#     ↳ #8927 'How to get a cash app refund by raising a dispute?' → dup of #8936
#     ↳ #8907 '"PCI Express Gen 4" SlotID display information sup' → dup of #8048
#     ↳ #8884 'VariablePolicy needs to replace VariableLock. (Bug' → dup of #10310
#     ↳ #8879 'Device path has wrong FV path if the boot manager ' → dup of #8845
#     ↳ #8848 'build.py does not return failed status code when D' → dup of #8064
#     ↳ #10083 'Do we still need the extra CoreConnectController()' → dup of #7168
#     ↳ #8779 'ArmPkg should declare library classes it defines i' → dup of #8776
#     ↳ #10046 'CpuDxe may allocate above 4GB memory for GDT (Bugz' → dup of #8680
#     ↳ #10031 'CoreValidateHandle() is unsafe. (Bugzilla Bug 3166' → dup of #8944
#     ↳ #10021 'BaseTools: Update the Basetools code for Python3.9' → dup of #8782
#     ↳ #8695 'GenCfgOpt.py caused Incremental build regression i' → dup of #8623
#     ↳ #10009 'TCG: EFI_EXIT_BOOT_SERVICES_INVOCATION is not reco' → dup of #9925
#     ↳ #8673 'X64 OVMF_CODE.fd with -DSMM_REQUIRE=TRUE -DSECURE_' → dup of #9139
#     ↳ #8661 'Build failed due to MAX_LONG_FILE_PATH being too s' → dup of #7016
#     ↳ #8639 'Structured PCD generated code has a casting error ' → dup of #8638
#     ↳ #8638 'Structured PCD generated code has a casting error ' → dup of #8639
#     ↳ #8610 'Timeout loops in XhciDxe take longer than specifie' → dup of #10422
#     ↳ #8590 'Add new memory attribute EFI_MEMORY_SP and EFI_MEM' → dup of #8237
#     ↳ #8585 'False positive issue in edk2 open Ci (Bugzilla Bug' → dup of #issue #8569
#     ↳ #9967 'License should be changed to BSD-2-Clause-Patent i' → dup of #7853
#     ↳ #9963 'CD command failed with Trailing period end of fold' → dup of #6747
#     ↳ #9956 'Request to add PatchCheck as CI Plugin (Bugzilla B' → dup of #9513
#     ↳ #8550 'Fix GetSupportedAndActivePcrs counter calculation ' → dup of #8903
#     ↳ #9951 'UT_LOG_xxx() messages are truncated (Bugzilla Bug ' → dup of #10199
#     ↳ #8526 'Allow OpenSSL config to support elliptic curve alg' → dup of #8995
#     ↳ #8484 'MdePkg/Include/Protocol/DevicePath.h lacks definit' → dup of #8483
#     ↳ #9917 '[ECC] AttributeError: 'NoneType' object has no att' → dup of #issue #5
#     ↳ #8480 'Ecc Fails with Python 3.8 (Bugzilla Bug 2707)' → dup of #8478
#     ↳ #8478 'ECC fails to run with Py38 interpreter (Bugzilla B' → dup of #8480
#     ↳ #8438 'EmulatorPkg WinHost Fails to compile with VS2019 (' → dup of #7474
#     ↳ #8437 'OvmfPkg/GenericQemuLoadImageLib: OVMF ia32x64 fail' → dup of #8404
#     ↳ #9899 'VerifyHashedFv ASSERTs should have conditionals (B' → dup of #8462
#     ↳ #8424 'Arrays might use invalid index (Bugzilla Bug 2614)' → dup of #6895
#     ↳ #8415 'Build fail with VS2019 (Bugzilla Bug 2604)' → dup of #8438
#     ↳ #9894 'HTTP Communication failed in Host Name Validation ' → dup of #8412
#     ↳ #8412 'HTTP Communication failed in Host Name Validation ' → dup of #9894
#     ↳ #8406 'Tcg2Dxe's ExitBootServices and ExitBootServicesFai' → dup of #9891
#     ↳ #9891 'Tcg2Dxe's ExitBootServices and ExitBootServicesFai' → dup of #8406
#     ↳ #8404 'OVMF IA32X64 no longer builds in common config aft' → dup of #8437
#     ↳ #8403 'Abstract DxeIpl from processor architecture (Bugzi' → dup of #10147
#     ↳ #9888 'BuildReport.py can throw UnicodeDecodeError except' → dup of #9703
#     ↳ #9887 'Incorrect ACPI PMTT device type values (Bugzilla B' → dup of #8949
#     ↳ #8380 'ECC issues in edk2/UefiCpuPkg (Bugzilla Bug 2553)' → dup of #7909
#     ↳ #8372 'GuidedSectionTools.txt is not generated correctly ' → dup of #6786
#     ↳ #8313 'UEFIPayloadPkg: coreboot on Intel DenvertonNS with' → dup of #10512
#     ↳ #9846 'Drop EDK Shell (EdkShellPkg) support (Bugzilla Bug' → dup of #7448
#     ↳ #8291 'CLANG9 TOOLS build OVMF failed with -D SECURE_BOOT' → dup of #10527
#     ↳ #8290 'BaseTools: Dsc Parser, included dsc file is parsed' → dup of #10142
#     ↳ #8250 'Fix variable runtime cache update logic (Bugzilla ' → dup of #8400
#     ↳ #8237 'Add UEFI 2.8 new memory attribute definitions (Bug' → dup of #8590
#     ↳ #8231 'Build warning due to calling removed sys.setdefaul' → dup of #8234
#     ↳ #8230 'Handling mixed UnicodeCollation with accordance to' → dup of #8175
#     ↳ #8212 'Fix spelling errors in SecurityPkg (Bugzilla Bug 2' → dup of #6633
#     ↳ #8202 'CryptoPkg dsc doesn't include every library and mo' → dup of #9102
#     ↳ #9796 'IScsiOnR2TRcvd Integer Overflow (Bugzilla Bug 2173' → dup of #9794
#     ↳ #9794 'IScsiReceivePdu integer overflow may lead to memor' → dup of #9796
#     ↳ #9790 'Ecc fails on python3 with antlr3 (Bugzilla Bug 214' → dup of #7778
#     ↳ #8143 'BaseTools will report "unresolved external symbol ' → dup of #8107
#     ↳ #8104 'PatchCheck .py is producing false positives in pat' → dup of #9513
#     ↳ #9765 'BaseTools: build will fail if running Edksetup.bat' → dup of #8105
#     ↳ #8064 'build returns exit code 0 when Postbuild process f' → dup of #8848
#     ↳ #8056 'BaseLib.h linked list macros should define "delete' → dup of #8051
#     ↳ #8051 'BaseLib.h linked list macros should define "delete' → dup of #8056
#     ↳ #8048 'pci command for gen 4 devices displays incorrect i' → dup of #9512
#     ↳ #9745 '[PciBus] SRIOV device may reserve additional one b' → dup of #10186
#     ↳ #7990 'Build cache cannot store the cache files for libra' → dup of #8008
#     ↳ #7974 '[OvmfPkg] Drop the consume of the ISA stack in PcA' → dup of #7975
#     ↳ #7973 '[CapsuleApp] Enhance Capsule-On-Disk related funct' → dup of #7748
#     ↳ #7933 'Build break if C file suffixes of named .C Under c' → dup of #7633
#     ↳ #7918 'Unlimited FV Recursion, round 2 (Bugzilla Bug 1743' → dup of #7473
#     ↳ #7895 'HTTPS boot is impossible on aarch64 (Bugzilla Bug ' → dup of #8030
#     ↳ #7872 'Move BaseUefiTianoCustomDecompressLib from IntelFr' → dup of #7858
#     ↳ #7865 'Enable multiple thread for MSVC compiler (Bugzilla' → dup of #7673
#     ↳ #7858 'Copy BaseUefiTianoCustomDecompressLib instance fro' → dup of #7872
#     ↳ #7853 'Update PatchCheck.py for change to BSD+Patent Lice' → dup of #7852
#     ↳ #9704 'Applications, including Windows pre-OS application' → dup of #9641
#     ↳ #7833 'CLANG Build issues with CLANG version 8.0.0.0 (tru' → dup of #9700
#     ↳ #9700 'CLANG Build issues with CLANG version 8.0.0.0 (tru' → dup of #7833
#     ↳ #9699 'CpuDxe driver is hard coded to only run if it is l' → dup of #8680
#     ↳ #7824 'parallelism / dependency tracking inside (not betw' → dup of #7673
#     ↳ #7778 'ECC fails to run after python3 migration. (Bugzill' → dup of #issue #8478
#     ↳ #9689 'IPv6 PXE and HTTP Boot can use the same IAID in th' → dup of #9688
#     ↳ #7750 'Add a PCD to skip Opal password prompt (Bugzilla B' → dup of #9730
#     ↳ #7748 'Enhance CapsuleApp to support Capsule-on-Disk feat' → dup of #7973
#     ↳ #7743 'VS EBC and XCODE build failure in MdeModulePkg Fau' → dup of #8481
#     ↳ #7739 'BaseTools: Build report generation fail when struc' → dup of #7789
#     ↳ #9681 'Exception with HeapGuard active and using FvSimple' → dup of #10045
#     ↳ #7721 'IpV6 NV data out of date causes Driver Binding Sta' → dup of #7720
#     ↳ #7719 'UEFI Drivers use UEFILib Protocol Un/Installation ' → dup of #7708
#     ↳ #9677 'Need library class check when parsing DSC file (Bu' → dup of #8107
#     ↳ #7710 'OPAL BlockSID setting disabled on boot (Bugzilla B' → dup of #7469
#     ↳ #7683 'Log Extended data to report status code when a boo' → dup of #7690
#     ↳ #7676 '[BaseTool] Build failed when there are DynamicHii ' → dup of #7789
#     ↳ #9668 'Edk2 multi-threaded build cannot compile reasonabl' → dup of #7824
#     ↳ #7657 'The CCFlag generated in PcdValueinit makefile is i' → dup of #10143
#     ↳ #7655 'Invalid line ending are detected in IntelFsp2Wrapp' → dup of #7651
#     ↳ #7653 'OvmfPkg with XCODE5 tool chain can't boot to shell' → dup of #7614
#     ↳ #7651 'IntelFsp2WrapperPkg: Fix line ending format issue ' → dup of #7655
#     ↳ #7646 'Remove IntelFrameworkModulePkg/Universal/FirmwareV' → dup of #7647
#     ↳ #7620 'TransferBuffer bug 1142 in NvmExpressPassthru.c ma' → dup of #7477
#     ↳ #7614 'XCODE Ovmf Boot to shell fail (Bugzilla Bug 1303)' → dup of #7653
#     ↳ #7612 'BaseTools: Enable Hash build by default (Bugzilla ' → dup of #7877
#     ↳ #7610 'Remove S3Lib and RecoveryLib (Bugzilla Bug 1299)' → dup of #7518
#     ↳ #7604 'Move network related components from MdeModulePkg ' → dup of #8180
#     ↳ #7602 'Remove UnixPkg from edk2/master (Bugzilla Bug 1291' → dup of #7447
#     ↳ #7592 '[UdfDxe] Additional checks are needed for ResolveS' → dup of #9718
#     ↳ #7590 'IA32 build failure in DxeCore/HeapGuard.c (Bugzill' → dup of #8294
#     ↳ #7542 'Tool build fail with vs2015 win7 64bit (Bugzilla B' → dup of #10513
#     ↳ #7526 'A GUID required is missing in SecCore INF (Bugzill' → dup of #7394
#     ↳ #7484 'Need to update the help information of ACPIVIEW (B' → dup of #7481
#     ↳ #7483 'No disable method for ACPI Table consistency check' → dup of #9635
#     ↳ #9635 'No disable method for ACPI Table consistency check' → dup of #7483
#     ↳ #7481 'Need to update the help information of ACPIVIEW (B' → dup of #7484
#     ↳ #7477 '[NvmExpressDxe] Fix the incorrect check for 'Trans' → dup of #7620
#     ↳ #7473 'Unlimited FV Recursion (Bugzilla Bug 1137)' → dup of #7918
#     ↳ #7469 'Opal BlockSid Setting Disabled after S3 (Bugzilla ' → dup of #7710
#     ↳ #7465 'There's still code executed on AP trying to access' → dup of #7348
#     ↳ #7447 'Remove UnixPkg from edk2/master (Bugzilla Bug 1106' → dup of #7602
#     ↳ #9627 'PcdDxeNxMemoryProtectionPolicy should reserve bits' → dup of #10526
#     ↳ #7374 'GenerateCapsule:MonotonicCount value exceed its ma' → dup of #7378
#     ↳ #7373 'GenerateCapsule: No error report when capoemflag e' → dup of #7378
#     ↳ #7366 'Redundant library class are defined in CpuDxe modu' → dup of #7369
#     ↳ #7358 'Declaration of __builtin_return_address() breaks c' → dup of #7025
#     ↳ #7348 'AP shouldn't call PEI services (Bugzilla Bug 993)' → dup of #7465
#     ↳ #9620 'CoreValidateHandle performance (Bugzilla Bug 988)' → dup of #8944
#     ↳ #7344 'UefiShellAcpiViewCommandLib fails to build under V' → dup of #7343
#     ↳ #9609 'Cannot change the current filesystem to fs0: (Bugz' → dup of #9571
#     ↳ #7240 'Enable XCODE5 tool chain for UefiCpuPkg with nasm ' → dup of #7003
#     ↳ #7233 'BaseTools: Complier error on VS2012 (Bugzilla Bug ' → dup of #6582
#     ↳ #9600 'undefined behavior of using default int type to pr' → dup of #7119
#     ↳ #7168 'Remove extra calls to ConnectController() from Sta' → dup of #10083
#     ↳ #7147 'Disable Bus Master on all P2P bridges at ExitBootS' → dup of #7095
#     ↳ #7139 'OvmfPkg/PlatformPei: set PcdOptionRomImageVerifica' → dup of #8148
#     ↳ #7116 'undefined behavior of left shift of int 1 by 31 in' → dup of #7114
#     ↳ #7095 'Bus Master Enable bit should not be set on P2P bri' → dup of #7147
#     ↳ #7038 'DEBUG print in AllocatePage causes lock ASSERT (Bu' → dup of #7340
#     ↳ #7031 'BaseTools: enhance error message for not supported' → dup of #7029
#     ↳ #7019 'Use /WHOLEARCHIVE in MSFT family DLINK_FLAGS to im' → dup of #7018
#     ↳ #7010 'Fix XCODE5 build issues with MdeModulePkg builds (' → dup of #8481
#     ↳ #9584 'XCODE tool chain not compatible with 4KB aligned P' → dup of #7085
#     ↳ #6980 '[BaseTools] EfiLdrImage : a segmentation fault fro' → dup of #6981
#     ↳ #6978 'Memory leak in SmiHandlerProfile related code (Bug' → dup of #6923
#     ↳ #6965 '[MpInitLib] Set AP state after X2APIC mode enabled' → dup of #7013
#     ↳ #6944 'UEFI PXE boot does not support a DHCP proxy (Bugzi' → dup of #8149
#     ↳ #6942 'BaseTools regression issue on the increment build ' → dup of #8124
#     ↳ #6932 'VfrCompiler doesn't support IMAGE_TOKEN in image s' → dup of #6924
#     ↳ #6926 'VFRcompiler needs to update IMAGE_TOKEN (Bugzilla ' → dup of #6924
#     ↳ #6924 'BaseTools: support  VfrCompiler  to use IMAGE_TOKE' → dup of #6932
#     ↳ #6923 'SmiHandlerProfile has a memory leak when Unregiste' → dup of #6978
#     ↳ #6915 'Upgrade CryptoPkg to use the latest OpenSSL 1.1.0x' → dup of #7218
#     ↳ #6908 'Abstract and refine UefiCpuPkg to be a generic pac' → dup of #9089
#     ↳ #6905 'Pkcs7Sign, Rsa2048Sha256Sign and Rsa2048Sha256Gene' → dup of #6634
#     ↳ #6896 'Overflowed array index Used (Bugzilla Bug 414)' → dup of #6895
#     ↳ #6895 'Overflowed array index (Bugzilla Bug 413)' → dup of #6896
#     ↳ #6886 'X64 build of EmulatorPkg crashes (Bugzilla Bug 403' → dup of #8684
#     ↳ #6873 'Delete boot option cause incorrect UI behavior (Bu' → dup of #6639
#     ↳ #6857 '[BDS] uses potential uninitialized variable when b' → dup of #9694
#     ↳ #6837 'Highlight menu was shown incorrectly in file explo' → dup of #6740
#     ↳ #6807 '[Build] CLANG38 toolchain missing NOOPT target (Bu' → dup of #10162
#     ↳ #6785 'Compiler warnings building basetools on Linux (Bug' → dup of #6798
#     ↳ #6783 'Incorrect local variable used in SubmitForSystem()' → dup of #10288
#     ↳ #9568 'MinnowMax memory init binary must guarantee that S' → dup of #6766
#     ↳ #9567 'MinnowMax Vlv2BinaryPkg DigitalThermalSensor binar' → dup of #6768
#     ↳ #9566 'MinnowMax Vlv2BinaryPkg PowerManagement2 binary SM' → dup of #6767
#     ↳ #6774 'Vlv2TbltDevicePkg binary support modules need to b' → dup of #6773
#     ↳ #6768 'MinnowMax has AP stuck in Busy state from DigitalT' → dup of #9567
#     ↳ #6767 'MinnowMax generates ASSERT from PowerManagement2 b' → dup of #9566
#     ↳ #6766 'MinnowMax memory init module does not produce alig' → dup of #9568
#     ↳ #6765 'Vlv2TbltDevicePkg platform builds do not complete ' → dup of #6764
#     ↳ #6747 '[ShellPkg] The 'cd' command does not work properly' → dup of #6645
#     ↳ #6743 '[BaseTools] Script file 'BuildEnv' is not supposed' → dup of #6706
#     ↳ #6734 'RAW format doesn't support "Align=Auto" while it s' → dup of #6725
#     ↳ #6723 'Update LZMA SDK from 4.65 to the latest 16.04 vers' → dup of #7359
#     ↳ #6689 'UefiCpuPkg: Update CpuId and MSR definitions with ' → dup of #7638
#     ↳ #6634 'In Linux, Rsa2048Sha256Sign and Pkcs7Sign are not ' → dup of #6905
#     ↳ #6633 'need fix typo in SecurityPkg (Bugzilla Bug 114)' → dup of #8212
#     ↳ #6626 'EDKII - Network stack : UEFI PXE boot issue with C' → dup of #6623
#     ↳ #6621 'Most edk2.tianocore.org links in EDK II are wrong ' → dup of #6577
#     ↳ #6614 'Add the build option "/D DISABLE_NEW_DEPRECATED_IN' → dup of #6677
#     ↳ #6608 'Installed Windows 10 OVMF SMP guest crashes when S' → dup of #6606
#     ↳ #6600 'ASSERT failure on QEMU (Bugzilla Bug 77)' → dup of #Issue #7959
#     ↳ #6597 'OVMF can't handly large VMs with qemu/kvm and linu' → dup of #7959
#     ↳ #6594 'Build failure with latest Xcode clang (Bugzilla Bu' → dup of #7833
#     ↳ #6582 'Basetools compile with VS2012 (Bugzilla Bug 56)' → dup of #7233
#     ↳ #6577 'Most edk2.tianocore.org links in EDK II are wrong ' → dup of #6574
#     ↳ #6565 'EDK Shell Locking Up after a few minutes (Bugzilla' → dup of #10139
#
# [3] PRIORITY CLASSIFICATION (model: qwen2.5:14b, sys: A)
#     Issues processed : 3546
#     high    : 1046
#     medium  : 1761
#     low     : 739
#
# [4] BUG ASSIGNMENT  (model: qwen2.5:14b, sys: A)
#     Issues evaluated : 3546
#     Correct          : 24/3546
#     Assignee distribution:
#       AshrafAliS          : 943
#       YangGangUEFI        : 786
#       lgao4               : 273
#       os-d                : 269
#       philnoh2            : 207
#       SaloniKasbekar      : 200
#       HunterChang030      : 179
#       Vogtinator          : 83
#       liyi77              : 76
#       BritChesley         : 57
#       NingFengGit         : 50
#       ardbiesheuvel       : 46
#       bexcran             : 45
#       mikebeaton          : 44
#       praravin            : 43
#       mdkinney            : 40
#       AndreasBBS          : 37
#       praveensankarn      : 35
#       yechao-w            : 24
#       vit9696             : 18
#       jxu023              : 17
#       wenbhou             : 16
#       deeglaze            : 15
#       Damien-Chen         : 11
#       makubacki           : 10
#       r1chard-lyu         : 9
#       EricGao2015         : 9
#       zevorn              : 3
#       zhurui22            : 1
#
# =================================================================
#   All results saved to: /home/nsiavash/triage_framework/results
# =================================================================
#
# =================================================================
#   RUNTIME SUMMARY
# =================================================================
#   Invalid Detection        : 2156.8s  (35.95 min)
#   Duplicate Detection      : 5716.8s  (95.28 min)
#   Priority Classification  : 32832.9s  (547.22 min)
#   Bug Assignment           : 22265.1s  (371.08 min)
#   ────────────────────────────────────────
#   Setup (CSV+index)        : 48.8s  (0.81 min)
#   Inference (LLM only)     : 62973.0s  (1049.55 min)
#   ────────────────────────────────────────
#   TOTAL (setup+inference)  : 63021.9s  (1050.36 min)
# =================================================================
# Runtime saved → /home/nsiavash/triage_framework/results/runtime_summary.csv
